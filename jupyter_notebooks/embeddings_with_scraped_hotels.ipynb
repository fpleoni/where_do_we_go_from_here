# %%
# Import libraries
from collections import Counter, OrderedDict
import datawig
from itertools import chain
from keras.layers import Input, Embedding, Dot, Reshape, Dense, Concatenate, Multiply
from keras.models import Model
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 500)
pd.options.display.max_colwidth = 1000
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-105-9ce418a1a0f5> in <module>
#       1 # Import libraries
#       2 from collections import Counter, OrderedDict
# ----> 3 import datawig
#       4 from itertools import chain
#       5 from keras.layers import Input, Embedding, Dot, Reshape, Dense, Concatenate, Multiply
#
# ModuleNotFoundError: No module named 'datawig'

# %%
# Path to file
hotels_path = "../data/hotels_com_scrape_v2.csv"

# Dataframe
hotels_df = pd.read_csv(hotels_path, header = None)

# Sanity check
hotels_df.head()
# Out:
#                      0                                       1    2  \
# 0  Masserberg, Germany                         Hotel Rennsteig  3.5
# 1  Masserberg, Germany                           Hotel Kammweg  3.0
# 2  Masserberg, Germany                    Landferienhaus Linde  5.0
# 3  Masserberg, Germany  Hotel und Landgasthaus Zur grünen Erle   na
# 4  Masserberg, Germany                    Berghotel Stutenhaus  3.5
#
#                                                                  3  \
# 0                    Am Badehaus 1, Masserberg, TH, 98666, Germany
# 1  Ehringshäuser Str. 4, Neustadt am Rennsteig, TH, 98701, Germany
# 2     Strasse am Berg 10, Schleusegrund, Thüringen, 98667, Germany
# 3         Erlauer Hauptstraße 69, Sankt Kilian, TH, 98553, Germany
# 4                     Stutenhausstraße 1, Suhl, TH, 98711, Germany
#
#                        4  \
# 0             Masserberg
# 1  Neustadt am Rennsteig
# 2          Schleusegrund
# 3           Sankt Kilian
# 4                   Suhl
#
#                                                            5     6  \
# 0  1.1 miles to City center, 0.4 miles to Skilift-Masserberg  83.0
# 1   5.0 miles to Masserberg, 4.4 miles to Skilift-Masserberg  63.0
# 2   4.2 miles to Masserberg, 5.2 miles to Skilift-Masserberg    na
# 3   8.7 miles to Masserberg, 9.6 miles to Skilift-Masserberg  74.0
# 4   8.9 miles to Masserberg, 9.3 miles to Skilift-Masserberg    na
#
#                                                                                                                                                                                                7
# 0      https://www.hotels.com/ho343089/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=1&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 1      https://www.hotels.com/ho265175/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=2&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 2  https://www.hotels.com/ho1067943424/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=3&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 3  https://www.hotels.com/ho1157676896/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=4&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 4   https://www.hotels.com/ho923498720/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=5&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3

# %%
# Rename columns
hotels_df.rename({0: "location", 1: "hotel_name", 2: "rating", 
                      3: "address", 4: "locality", 5: "landmark", 
                      6: "price", 7: "URL"}, inplace = True, axis = 1)

# %%
# Replace na values with np.nan
hotels_df["price"] = hotels_df["price"].replace("na", np.nan)

# %%
# Convert price to int
f = lambda x: float(x) if x != np.nan else np.nan
hotels_df["price"] = hotels_df["price"].map(f)

# %%
# Replace na values with np.nan
hotels_df["rating"] = hotels_df["rating"].replace("na", np.nan)

# Convert rating to float
hotels_df["rating"] = hotels_df["rating"].map(f)

# %%
# Convert all landmarks to strings
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: str(x))

# %%
# Convert all landmarks to lowercase
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: x.lower())

# %%
# Split landmark
hotels_df["landmark"] = hotels_df["landmark"].str.split("\n")

# %%
# Split location
location_df = hotels_df["location"].str.split(",", expand = True)

# %%
# Rename landmark columns
location_df.rename({0: "city", 1: "country"}, inplace = True, axis = 1)

# %%
location_df.head()
# Out:
#          city   country
# 0  Masserberg   Germany
# 1  Masserberg   Germany
# 2  Masserberg   Germany
# 3  Masserberg   Germany
# 4  Masserberg   Germany

# %%
# Merge landmarks_df with hotels_df
hotels_df = pd.merge(location_df, hotels_df[["hotel_name", "rating", "address", 
                                             "locality", "price", "landmark", "URL"]], left_index = True, 
                          right_index = True, how = "right")

# %%
# Sanity Check
hotels_df.head(100)
# Out:
#                city        country  \
# 0        Masserberg        Germany
# 1        Masserberg        Germany
# 2        Masserberg        Germany
# 3        Masserberg        Germany
# 4        Masserberg        Germany
# 5        Masserberg        Germany
# 6        Masserberg        Germany
# 7        Masserberg        Germany
# 8        Masserberg        Germany
# 9        Masserberg        Germany
# 10       Masserberg        Germany
# 11       Masserberg        Germany
# 12       Masserberg        Germany
# 13       Masserberg        Germany
# 14       Masserberg        Germany
# 15       Masserberg        Germany
# 16       Masserberg        Germany
# 17       Masserberg        Germany
# 18       Masserberg        Germany
# 19         Fourways   South Africa
# 20         Fourways   South Africa
# 21         Fourways   South Africa
# 22         Fourways   South Africa
# 23         Fourways   South Africa
# 24         Fourways   South Africa
# 25         Fourways   South Africa
# 26      Albuquerque            USA
# 27      Albuquerque            USA
# 28      Albuquerque            USA
# 29      Albuquerque            USA
# 30      Albuquerque            USA
# 31  Caleta de Fuste          Spain
# 32  Caleta de Fuste          Spain
# 33  Caleta de Fuste          Spain
# 34  Caleta de Fuste          Spain
# 35  Caleta de Fuste          Spain
# 36       Allensbach        Germany
# 37       Allensbach        Germany
# 38       Allensbach        Germany
# 39       Allensbach        Germany
# 40       Allensbach        Germany
# 41       Allensbach        Germany
# 42       Allensbach        Germany
# 43       Allensbach        Germany
# 44       Allensbach        Germany
# 45       Allensbach        Germany
# 46       Allensbach        Germany
# 47       Allensbach        Germany
# 48       Allensbach        Germany
# 49       Allensbach        Germany
# 50       Allensbach        Germany
# 51       Allensbach        Germany
# 52       Allensbach        Germany
# 53       Allensbach        Germany
# 54       Allensbach        Germany
# 55       Allensbach        Germany
# 56       Allensbach        Germany
# 57       Allensbach        Germany
# 58       Allensbach        Germany
# 59       Allensbach        Germany
# 60       Allensbach        Germany
# 61       Allensbach        Germany
# 62       Allensbach        Germany
# 63       Allensbach        Germany
# 64       Allensbach        Germany
# 65       Allensbach        Germany
# 66       Allensbach        Germany
# 67       Allensbach        Germany
# 68       Allensbach        Germany
# 69       Allensbach        Germany
# 70       Allensbach        Germany
# 71       Allensbach        Germany
# 72             Rome          Italy
# 73             Rome          Italy
# 74             Rome          Italy
# 75             Rome          Italy
# 76             Rome          Italy
# 77             Rome          Italy
# 78             Rome          Italy
# 79             Rome          Italy
# 80             Rome          Italy
# 81             Rome          Italy
# 82             Rome          Italy
# 83             Rome          Italy
# 53                                        Hemishoferstrasse 87, Stein am Rhein, 8260, Switzerland
# 54                                        Siedlung 5A, Immenstaad am Bodensee, BW, 88090, Germany
# 55                                                1 Unteraustrasse, Sulgen, TG, 8583, Switzerland
# 56                         Markdorferstr. 36, Friedrichshafen, Baden Wuerttemberg, 88048, Germany
# 57                                                   Steibensteg 10, Markdorf, BW, 88677, Germany
# 58                                                   Hauptstrasse 15, Gachnang, 8546, Switzerland
# 59                                    Waggershauser Str. 120, Friedrichshafen, BW, 88045, Germany
# 60                                            Bahnhofplatz 2, Friedrichshafen, BW, 88045, Germany
# 61                                             Kirchhofplatz 7-9, Schaffhausen, 8200, Switzerland
# 62                                               Bahnhofstrasse 107, Uzwil, SG, 9240, Switzerland
# 63                                          Stadthausstrasse 4, Winterthur, ZH, 8400, Switzerland
# 64                                          Lagerhausstrasse 6, Winterthur, ZH, 8400, Switzerland
# 65                              Hauptstraße 136, Meckenbeuren, Baden-Wuerttemberg, 88074, Germany
# 66                                   Friedrichshafener Str. 16/1, Langenargen, BW, 88085, Germany
# 67                                                         Neumühle 1, Beuron, BW, 88631, Germany
# 68                                              Randenstrasse 65, Schaffhausen, 8200, Switzerland
# 69                                               5 Hirschenstrasse, Gossau, SG, 9200, Switzerland
# 70                                                 Kirchstraße 3, Langenargen, BW, 88085, Germany
# 71                                            Promenadenstrasse 7, Kreuzlingen, 8280, Switzerland
# 72                                                        Via della Reginella 2, Rome, 186, Italy
# 73                                                              Via Emilia 88, Rome, 00188, Italy
# 74                                                        Via Nazionale 7, Rome, RM, 00184, Italy
# 75                                                  Via Muzio Clementi 81, Rome, RM, 00193, Italy
# 76                                                    Via dei Chiavari 20, Rome, RM, 00186, Italy
# 77                                                 Via Giuseppe Zanardelli 36, Rome, 00186, Italy
# 78                                                        Via Ludovisi 15, Rome, RM, 00187, Italy
# 79                                                       Via Palestro, 64, Rome, RM, 00185, Italy
# 80                                                  Via Mario dé Fiori 61, Rome, RM, 00187, Italy
# 81                                                       Borgo Sant Angelo 19, Rome, 00193, Italy
# 82                                                         Via Firenze, 8, Rome, RM, 00184, Italy
# 83                                                Via del Macherino 46, Rome, Lazio, 00193, Italy
# 84                                                       Vicolo del Bottino 8, Rome, 00187, Italy
# 85                                                    Via Gregoriana 25, Rome, Roma, 00187, Italy
# 86                                                          Via Milano 42, Rome, RM, 00184, Italy
# 87                                                    Via Zucchelli 1/c, Rome, Roma, 00187, Italy
# 88                                                     Viale Vaticano, 99, Rome, RM, 00165, Italy
# 89                                                 Largo della Sapienza 8, Rome, RM, 00186, Italy
# 90                                                     Via Giosuè Carducci, 2, Rome, 00187, Italy
# 91                                                            Via Palermo, 67, Rome, 00184, Italy
# 92                                                       Viale Trastevere, 75, Rome, 00153, Italy
# 93                                            Largo Visconti Venosta, 228, Rome, RM, 00184, Italy
# 94                                                         Via Flavia 106, Rome, RM, 00187, Italy
# 95                                                         Via del Tritone 87, Rome, 00187, Italy
# 96                                               Via Di Porta Pinciana 14, Rome, RM, 00187, Italy
# 97                                   Via Licia 7, Rome, Città Metropolitana di Roma, 00183, Italy
# 98                                                       Via Aureliana 39, Rome, RM, 00187, Italy
# 99                                 Piazza Dell'Esquilino, 29, Rione Monti, Rome, RM, 00185, Italy
#
#                         locality  price  \
# 0                     Masserberg   83.0
# 1          Neustadt am Rennsteig   63.0
# 2                  Schleusegrund    NaN
# 3                   Sankt Kilian   74.0
# 4                           Suhl    NaN
# 5                        Ilmenau  123.0
# 6                       Steinach   80.0
# 7                           Suhl  106.0
# 8                           Suhl    NaN
# 9                       Gehlberg   61.0
# 10                       Oberhof    NaN
# 11                       Oberhof    NaN
# 12                       Oberhof    NaN
# 13                       Oberhof    NaN
# 14          Bad Colberg-Heldburg   71.0
# 15                Saalfeld-Saale   67.0
# 16                    Luisenthal    NaN
# 17          Steinbach-Hallenberg    NaN
# 18                          Suhl    NaN
# 19                       Sandton    NaN
# 20                       Sandton  125.0
# 21                       Sandton    NaN
# 22                       Sandton    NaN
# 23                       Sandton    NaN
# 24                       Sandton   57.0
# 25                       Sandton    NaN
# 26                   Albuquerque    NaN
# 27                   Albuquerque  146.0
# 28                   Albuquerque    NaN
# 29                   Albuquerque    NaN
# 30                   Albuquerque    NaN
# 31               Caleta de Fuste    NaN
# 32               Caleta de Fuste   65.0
# 33               Caleta de Fuste    NaN
# 34               Caleta de Fuste    NaN
# 35               Caleta de Fuste    NaN
# 36     Schaffhausen, Switzerland  435.0
# 37                     Reichenau  150.0
# 38               Friedrichshafen    NaN
# 39                     Reichenau  150.0
# 40        Radolfzell am Bodensee    NaN
# 41        Radolfzell am Bodensee  169.0
# 42                    Gaienhofen  134.0
# 43                      Konstanz  240.0
# 44                      Konstanz  180.0
# 45                      Konstanz  173.0
# 46                      Konstanz    NaN
# 47      Kreuzlingen, Switzerland  159.0
# 48          Uhldingen-Muehlhofen  142.0
# 49                       Stetten   76.0
# 50           Ramsen, Switzerland  138.0
# 51       Guettingen, Switzerland  156.0
# 52  Warth-Weiningen, Switzerland  205.0
# 53   Stein am Rhein, Switzerland   93.0
# 54        Immenstaad am Bodensee    NaN
# 55           Sulgen, Switzerland    NaN
# 56               Friedrichshafen    NaN
# 57                      Markdorf    NaN
# 58         Gachnang, Switzerland  150.0
# 59               Friedrichshafen   78.0
# 60               Friedrichshafen  206.0
# 61     Schaffhausen, Switzerland  157.0
# 62            Uzwil, Switzerland  123.0
# 63       Winterthur, Switzerland  249.0
# 64       Winterthur, Switzerland  145.0
# 65                  Meckenbeuren    NaN
# 66                   Langenargen    NaN
# 67                        Beuron    NaN
# 68     Schaffhausen, Switzerland   76.0
# 69           Gossau, Switzerland    NaN
# 70                   Langenargen   63.0
# 71      Kreuzlingen, Switzerland   93.0
# 72                        Navona   90.0
# 73              Rome City Centre  149.0
# 74                    Repubblica    NaN
# 75              Rome City Centre  164.0
# 76                        Navona   98.0
# 77              Rome City Centre  101.0
# 78              Rome City Centre  207.0
# 79   Rione XVIII Castro Pretorio  138.0
# 80              Rome City Centre   84.0
# 81                       Vatican  100.0
# 82                    Repubblica    NaN
# 83                       Vatican  111.0
# 84              Rome City Centre  299.0
# 85              Rome City Centre  109.0
# 86                    Repubblica  147.0
# 87              Rome City Centre   80.0
# 88                       Vatican  134.0
# 89                        Navona  244.0
# 90                   Sallustiano   70.0
# 91                    Repubblica   90.0
# 92                    Trastevere   93.0
# 93                         Monti  127.0
# 94                   Sallustiano  108.0
# 95                Rione II Trevi  158.0
# 96              Rome City Centre  285.0
# 97                  San Giovanni  105.0
# 98                   Sallustiano  112.0
# 99                         Monti  171.0
#
#                                                                                               landmark  \
# 0                                          [1.1 miles to city center, 0.4 miles to skilift-masserberg]
# 1                                           [5.0 miles to masserberg, 4.4 miles to skilift-masserberg]
# 2                                           [4.2 miles to masserberg, 5.2 miles to skilift-masserberg]
# 3                                           [8.7 miles to masserberg, 9.6 miles to skilift-masserberg]
# 4                                           [8.9 miles to masserberg, 9.3 miles to skilift-masserberg]
# 5                                             [10 miles to masserberg, 10 miles to skilift-masserberg]
# 6                                             [11 miles to masserberg, 10 miles to skilift-masserberg]
# 7                                             [13 miles to masserberg, 13 miles to skilift-masserberg]
# 8                                             [13 miles to masserberg, 14 miles to skilift-masserberg]
# 9                                             [13 miles to masserberg, 13 miles to skilift-masserberg]
# 10                                            [16 miles to masserberg, 16 miles to skilift-masserberg]
# 11                                            [17 miles to masserberg, 17 miles to skilift-masserberg]
# 12                                            [17 miles to masserberg, 17 miles to skilift-masserberg]
# 13                                            [17 miles to masserberg, 17 miles to skilift-masserberg]
# 14                                            [18 miles to masserberg, 19 miles to skilift-masserberg]
# 15                                            [21 miles to masserberg, 19 miles to skilift-masserberg]
# 16                                            [21 miles to masserberg, 21 miles to skilift-masserberg]
# 17                                            [21 miles to masserberg, 22 miles to skilift-masserberg]
# 18                                            [13 miles to masserberg, 14 miles to skilift-masserberg]
# 19                         [3.2 miles to city center, 15 miles to johannesburg (jnb-o.r. tambo intl.)]
# 20                         [3.3 miles to city center, 11 miles to johannesburg (jnb-o.r. tambo intl.)]
# 21                         [3.4 miles to city center, 11 miles to johannesburg (jnb-o.r. tambo intl.)]
# 22                         [2.3 miles to city center, 11 miles to johannesburg (jnb-o.r. tambo intl.)]
# 23                         [2.9 miles to city center, 12 miles to johannesburg (jnb-o.r. tambo intl.)]
# 24                         [4.5 miles to city center, 16 miles to johannesburg (jnb-o.r. tambo intl.)]
# 25                         [4.2 miles to city center, 16 miles to johannesburg (jnb-o.r. tambo intl.)]
# 26  [4.3 miles to albuquerque international sunport (abq), 1.4 miles to albuquerque convention center]
# 27  [4.3 miles to albuquerque international sunport (abq), 4.3 miles to albuquerque convention center]
# 28   [8.3 miles to albuquerque international sunport (abq), 10 miles to albuquerque convention center]
# 29  [4.8 miles to albuquerque international sunport (abq), 2.3 miles to albuquerque convention center]
# 30  [4.1 miles to albuquerque international sunport (abq), 1.1 miles to albuquerque convention center]
# 31          [3.8 miles to puerto del rosario (fue-fuerteventura), 0.6 miles to caleta de fuste marina]
q-room-0-children=0&pa=4&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              https://www.hotels.com/ho923498720/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=5&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho82495104/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=6&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              https://www.hotels.com/ho806571904/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=7&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho80825504/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=8&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 https://www.hotels.com/ho666446/?q-check-out=2020-08-29&FPQ=4&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=9&tab=description&JHR=5&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             https://www.hotels.com/ho600906528/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=10&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho465616/?q-check-out=2020-08-29&FPQ=6&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=11&tab=description&JHR=9&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# ...
# 85                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho652639/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=14&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho438248/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=15&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 87                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            https://www.hotels.com/ho926991680/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=16&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 88                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho281494/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=17&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho470262/?q-check-out=2020-08-29&FPQ=4&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=18&tab=description&JHR=5&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            https://www.hotels.com/ho711273152/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=19&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho664879/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=20&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho691258/?q-check-out=2020-08-29&FPQ=2&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=21&tab=description&JHR=2&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho684785/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=22&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho129631/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=23&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 95                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho606454/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=24&tab=description&JHR=4&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho194079/?q-check-out=2020-08-29&FPQ=4&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=25&tab=description&JHR=5&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            https://www.hotels.com/ho973601600/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=26&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho172045/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=27&tab=description&JHR=3&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               https://www.hotels.com/ho510090/?q-check-out=2020-08-29&FPQ=3&q-check-in=2020-08-27&WOE=6&WOD=4&q-room-0-children=0&pa=28&tab=description&JHR=4&q-room-0-adults=2&YGF=14&MGT=2&ZSX=0&SYE=3

# %%
# Prepare city column

# Convert all cities to lowercase
hotels_df["city"] = hotels_df["city"].apply(lambda x: x.lower())

city_list = hotels_df["city"].tolist()

# Find set of unique cities and convert to a list
unique_cities = list(set(city_list))

# Create indexes for each city
city_index = {city: idx for idx, city in enumerate(unique_cities)}
index_city = {idx: city for city, idx in city_index.items()}

# %%
# Prepare country column

# Convert all countries to lowercase
hotels_df["country"] = hotels_df["country"].apply(lambda x: x.lower())

country_list = hotels_df["country"].tolist()

# Find set of unique countries and convert to a list
unique_countries = list(set(country_list))

# Create indexes for each property
country_index = {country: idx for idx, country in enumerate(unique_countries)}
index_country = {idx: country for country, idx in country_index.items()}

# %%
# Prepare hotel_name column

# Convert all hotels to lowercase
hotels_df["hotel_name"] = hotels_df["hotel_name"].apply(lambda x: x.lower())

# Create hotel names list
hotels_list = hotels_df["hotel_name"].tolist()

# Create indexes for each hotel
hotel_index = {hotel: idx for idx, hotel in enumerate(hotels_list)}
index_hotel = {idx: hotel for hotel, idx in hotel_index.items()}

# %%
# Create ratings list
rating_list = hotels_df["rating"].tolist()

# Find set of unique ratings and convert to a list
unique_ratings = list(set(rating_list))

# Create indexes for each rating
rating_index = {rating: idx for idx, rating in enumerate(rating_list)}
index_rating = {idx: rating for rating, idx in price_index.items()}

# %%
# Create ratings list
rating_list = hotels_df["rating"].tolist()

# Find set of unique ratings and convert to a list
unique_ratings = list(set(rating_list))

# Create indexes for each rating
rating_index = {rating: idx for idx, rating in enumerate(rating_list)}
index_rating = {idx: rating for rating, idx in rating_index.items()}

# %%
# Prepare locality column

# Convert all hotels to lowercase
hotels_df["locality"] = hotels_df["locality"].apply(lambda x: x.lower())

# Create hotel names list
locality_list = hotels_df["locality"].tolist()
unique_localities = list(set(locality_list))

# Create indexes for each hotel
locality_index = {locality: idx for idx, locality in enumerate(unique_localities)}
index_locality = {idx: locality for locality, idx in locality_index.items()}

# %%
# Create price list
price_list = hotels_df["price"].tolist()

# Create indexes for each price
price_index = {price: idx for idx, price in enumerate(price_list)}
index_price = {idx: price for price, idx in price_index.items()}

# %%
# Prepare locality column

# Create hotel names list
landmark_list = hotels_df["landmark"].tolist()

# Find set of unique properties and convert to a list
unique_landmarks = list(chain(*[list(set(landmarks)) for landmarks in landmark_list]))
unique_landmarks = list(set(unique_landmarks))

# Create indexes for each hotel
landmark_index = {landmark: idx for idx, landmark in enumerate(unique_landmarks)}
index_landmark = {idx: landmark for landmark, idx in landmark_index.items()}

# %%
# Build tuples to train embedding neural network
hotel_tuples = []

# Iterate through each row of dataframe
for index, row in hotels_df.iterrows():
    # Iterate through the properties in the item
    hotel_tuples.extend((city_index[hotels_df.at[index, "city"]], country_index[hotels_df.at[index, "country"]],
                         hotel_index[hotels_df.at[index, "hotel_name"]], rating_index[hotels_df.at[index, "rating"]],
                         locality_index[hotels_df.at[index, "locality"]], price_index[hotels_df.at[index, "price"]],
                         landmark_index[landmark]) for landmark in hotels_df.at[index, "landmark"] 
                         if landmark.lower() in unique_landmarks)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-965281bac7d7> in <module>
#       8                          hotel_index[hotels_df.at[index, "hotel_name"]], rating_index[hotels_df.at[index, "rating"]],
#       9                          locality_index[hotels_df.at[index, "locality"]], price_index[hotels_df.at[index, "price"]],
# ---> 10                          landmark_index[landmark]) for landmark in hotels_df.at[index, "landmark"]
#      11                          if landmark.lower() in unique_landmarks)
#
# <ipython-input-109-965281bac7d7> in <genexpr>(.0)
#       9                          locality_index[hotels_df.at[index, "locality"]], price_index[hotels_df.at[index, "price"]],
#      10                          landmark_index[landmark]) for landmark in hotels_df.at[index, "landmark"]
# ---> 11                          if landmark.lower() in unique_landmarks)
#
# KeyError: nan

# %%
# Generator for training samples
def generate_batch(tuples, n_positive = 75, negative_ratio = 2.0):
    
    pairs_set = set(tuples)
    
    batch_size = n_positive * (1 + negative_ratio)
    batch = np.zeros((batch_size, 5))
    
    # Label for negative examples
    neg_label = 0
    
    # This creates a generator
    while True:
        # randomly choose positive examples
        for idx, (item_id, property_id, price_id, location_id) in enumerate(random.sample(tuples, n_positive)):
            batch[idx, :] = (item_id, property_id, price_id, location_id, 1)

        # Increment idx by 1
        idx += 1
        
        # Add negative examples until reach batch size
        while idx < batch_size:
            
            # random selection
            random_item = random.randrange(len(item_list))
            random_property = random.randrange(len(unique_properties))
            random_price = random.randrange(len(price_list))
            random_location = random.randrange(len(unique_locations))
            
            # Check to make sure this is not a positive example
            if (random_item, random_property, random_price, random_location) not in pairs_set:
                
                # Add to batch and increment index
                batch[idx, :] = (random_item, random_property, random_price, random_location, neg_label)
                idx += 1
                
        # Make sure to shuffle order
        np.random.shuffle(batch)
        yield {"item": batch[:, 0], "property": batch[:, 1], "price": batch[:, 2], 
               "location": batch[:, 3]}, batch[:, 4]

# %%
# Create embeddings

# TSNE

# Calculate missing values for price, and ratings

# Re create embeddings

# Regression and classification?
