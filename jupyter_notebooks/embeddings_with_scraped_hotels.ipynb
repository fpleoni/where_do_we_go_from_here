# %%
# Import libraries
from collections import Counter, OrderedDict
# import datawig
from itertools import chain
from keras.layers import Input, Embedding, Add, Reshape, Dense, Multiply, GlobalMaxPool1D
from keras.models import Model
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 500)
pd.options.display.max_colwidth = 1000
import random

# %%
# Path to file
hotels_path = "../data/hotels_com_scrape_v3.csv"

# Dataframe
hotels_df = pd.read_csv(hotels_path, header = None)

# Sanity check
hotels_df.head()
# Out:
#                       0                                      1    2    3  \
# 0  Mutterstadt, Germany                        RheinCity Hotel  4.0    4
# 1  Mutterstadt, Germany  NYX Hotel Mannheim by Leonardo Hotels  4.0   14
# 2  Mutterstadt, Germany           Radisson Blu Hotel, Mannheim  4.5  387
# 3  Mutterstadt, Germany        ACHAT Comfort Frankenthal/Pfalz  3.5   64
# 4  Mutterstadt, Germany                        Relax Apartment   na   na
#
#                                                     4             5  \
# 0  Zollhofstraße 11, Ludwigshafen, RP, 67059, Germany  Ludwigshafen
# 1              F4, 4-11, Mannheim, BW, 68159, Germany      Mannheim
# 2           Quadrant Q7, 27, Mannheim, 68161, Germany      Mannheim
# 3    Mahlastrasse 18, Frankenthal, RP, 67227, Germany   Frankenthal
# 4                  F4 14-15, Mannheim, 68159, Germany      Mannheim
#
#                                                        6      7  \
# ...

# %%
# Rename columns
hotels_df.rename({0: "location", 1: "hotel_name", 2: "rating", 3: "popularity_rating", 
                      4: "address", 5: "locality", 6: "landmark", 
                      7: "price", 8: "URL"}, inplace = True, axis = 1)

# %%
# Check for null values
hotels_df.isna().sum()
# Out:
# location              0
# hotel_name            0
# rating                0
# popularity_rating     0
# address               0
# locality              0
# landmark             69
# price                 0
# URL                   0
# dtype: int64

# %%
# Split location
location_df = hotels_df["location"].str.split(",", expand = True)

# %%
# Rename landmark columns
location_df.rename({0: "city", 1: "country"}, inplace = True, axis = 1)

# %%
location_df.head()
# Out:
#           city   country
# 0  Mutterstadt   Germany
# 1  Mutterstadt   Germany
# 2  Mutterstadt   Germany
# 3  Mutterstadt   Germany
# 4  Mutterstadt   Germany

# %%
# Merge landmarks_df with hotels_df
hotels_df = pd.merge(location_df, hotels_df[["hotel_name", "rating", "address", "popularity_rating",
                                             "locality", "price", "landmark", "URL"]], left_index = True, 
                          right_index = True, how = "right")

# %%
# Check the null values in the landmark column
print(hotels_df[hotels_df["landmark"].isnull()])
# Out:
#                     city     country  \
# 7045              Brezno    Slovakia
# 7046              Brezno    Slovakia
# 7047              Brezno    Slovakia
# 7048              Brezno    Slovakia
# 7049              Brezno    Slovakia
# 7050              Brezno    Slovakia
# 7051              Brezno    Slovakia
# 7052              Brezno    Slovakia
# 7053              Brezno    Slovakia
# 9123         Leitariegos       Spain
# 9124         Leitariegos       Spain
# 9125         Leitariegos       Spain
# 9126         Leitariegos       Spain
# 9127         Leitariegos       Spain
# 9128         Leitariegos       Spain
# 9129         Leitariegos       Spain
# 10682             Araras      Brazil
# 10683             Araras      Brazil
# 10684             Araras      Brazil
# 10685             Araras      Brazil
# 10686             Araras      Brazil
# 10687             Araras      Brazil
# 10688             Araras      Brazil
# 10689             Araras      Brazil
# ...

# %%
# Input 69 values manually

# Slovakia
hotels_df.loc[hotels_df.index[7045], "landmark"] = "5.6 miles to Ethnographic Museum"
hotels_df.loc[hotels_df.index[7046], "landmark"] = "4.4 miles to Liptovsky Mara"
hotels_df.loc[hotels_df.index[7047], "landmark"] = "4.1 miles to Chopok"
hotels_df.loc[hotels_df.index[7048], "landmark"] = "5.8 miles to Gothal"
hotels_df.loc[hotels_df.index[7049], "landmark"] = "3.9 Museum of Nature Protection and Speleology"
hotels_df.loc[hotels_df.index[7050], "landmark"] = "3.1 Museum of Nature Protection and Speleology"
hotels_df.loc[hotels_df.index[7051], "landmark"] = "4.9 miles to Namestie Osloboditelov"
hotels_df.loc[hotels_df.index[7052], "landmark"] = "9.0 miles to Wooden church Hronsek UNESCO"
hotels_df.loc[hotels_df.index[7053], "landmark"] = "6.0 miles to Archaeological Museum Havránok"

# Spain
hotels_df.loc[hotels_df.index[9123], "landmark"] = "3.5 miles to Las Rozas Dam"
hotels_df.loc[hotels_df.index[9124], "landmark"] = "13.2 miles to Poza Julia Museum"
hotels_df.loc[hotels_df.index[9125], "landmark"] = "3.2 miles to Muniellos Nature Reserve"
hotels_df.loc[hotels_df.index[9126], "landmark"] = "6.7 miles to Muniellos Nature Reserve"
hotels_df.loc[hotels_df.index[9127], "landmark"] = "7.4 miles to Dominio de Tares"
hotels_df.loc[hotels_df.index[9128], "landmark"] = "7.3 miles to Dominio de Tares"
hotels_df.loc[hotels_df.index[9129], "landmark"] = "9.1 miles to Saliencia Lakes"

# Brazil
hotels_df.loc[hotels_df.index[10682], "landmark"] = "3.4 miles to Itapaiva Castle"
hotels_df.loc[hotels_df.index[10683], "landmark"] = "6.8 miles to Itapaiva Castle"
hotels_df.loc[hotels_df.index[10684], "landmark"] = "1.0 miles to Imperial Museum"
hotels_df.loc[hotels_df.index[10685], "landmark"] = "7.2 miles to Itapaiva Castle"
hotels_df.loc[hotels_df.index[10686], "landmark"] = "1.2 miles to Imperial Museum"
hotels_df.loc[hotels_df.index[10687], "landmark"] = "4.7 miles to Itapaiva Castle"
hotels_df.loc[hotels_df.index[10688], "landmark"] = "8.2 miles to Ferreira da Cunha Museum of Arms"
hotels_df.loc[hotels_df.index[10689], "landmark"] = "2.3 miles to Judith Fountain"

# Germany
hotels_df.loc[hotels_df.index[13272], "landmark"] = "27.6 miles to Ore Mountain Museum"
hotels_df.loc[hotels_df.index[13273], "landmark"] = "5.7 miles to Gottfried Silbermann Museum"
hotels_df.loc[hotels_df.index[13274], "landmark"] = "2.4 miles to Altenberg Bobsleigh"
hotels_df.loc[hotels_df.index[13275], "landmark"] = "3.9 miles to Pferdegöpel auf dem Rudolphschacht"
hotels_df.loc[hotels_df.index[13276], "landmark"] = "6.6 miles to Ore Mountain Museum"
hotels_df.loc[hotels_df.index[13277], "landmark"] = "4.5 miles to Saidenbach Dam"
hotels_df.loc[hotels_df.index[13278], "landmark"] = "3.5 miles to Saidenbach Dam"
hotels_df.loc[hotels_df.index[13279], "landmark"] = "9.1 miles to Wolkenstein Castle"
hotels_df.loc[hotels_df.index[13280], "landmark"] = "4.2 miles to Wolkenstein Castle"
hotels_df.loc[hotels_df.index[13283], "landmark"] = "21.2 miles to Ore Mountain Museum"

# Brazil
hotels_df.loc[hotels_df.index[15161], "landmark"] = "2.8 miles to Santana do Riacho Waterfall"
hotels_df.loc[hotels_df.index[15162], "landmark"] = "13.2 miles to Andorinhas Waterfall"
hotels_df.loc[hotels_df.index[15163], "landmark"] = "4.0 miles to Santana do Riacho Waterfall"
hotels_df.loc[hotels_df.index[15164], "landmark"] = "13.2 miles to Andorinhas Waterfall"
hotels_df.loc[hotels_df.index[15165], "landmark"] = "14.8 miles to Peter Lund Museum"
hotels_df.loc[hotels_df.index[15166], "landmark"] = "2.4 miles to Santana do Riacho Waterfall"

# Sri Lanka
hotels_df.loc[hotels_df.index[15214], "landmark"] = "2.8 miles to Kushtarajagala Statue"
hotels_df.loc[hotels_df.index[15215], "landmark"] = "5.9 miles to Mirissa Beach"
hotels_df.loc[hotels_df.index[15216], "landmark"] = "2.0 miles to Mirissa Beach"
hotels_df.loc[hotels_df.index[15217], "landmark"] = "5.9 miles to Mirissa Beach "
hotels_df.loc[hotels_df.index[15218], "landmark"] = "2.8 miles to Kushtarajagala Statue"
hotels_df.loc[hotels_df.index[15219], "landmark"] = "4.8 miles to Mirissa Beach"

# Russia
hotels_df.loc[hotels_df.index[18137], "landmark"] = "1.2 miles to City Center"
hotels_df.loc[hotels_df.index[18138], "landmark"] = "6.8 miles to City Center"
hotels_df.loc[hotels_df.index[18139], "landmark"] = "4.8 miles to City Center"

# Spain
hotels_df.loc[hotels_df.index[18545], "landmark"] = "0.2 miles to Les Platgetes"
hotels_df.loc[hotels_df.index[18546], "landmark"] = "0.5 miles to Arenal-Bol Beach"
hotels_df.loc[hotels_df.index[18547], "landmark"] = "8.3 miles to Denia Marina"
hotels_df.loc[hotels_df.index[18548], "landmark"] = "6.9 miles to Denia Marina"
hotels_df.loc[hotels_df.index[18549], "landmark"] = "2.4 miles Denia Marina"
hotels_df.loc[hotels_df.index[18550], "landmark"] = "2.1 miles to Mirador Cronistas de Espana"
hotels_df.loc[hotels_df.index[18551], "landmark"] = "2.1 miles to Cova de L'Aigua"
hotels_df.loc[hotels_df.index[18552], "landmark"] = "3.0 miles to Cova de L'Aigua"
hotels_df.loc[hotels_df.index[18553], "landmark"] = "2.7 miles to Albir Beach"
hotels_df.loc[hotels_df.index[18554], "landmark"] = "0.5 miles to Mirador Cronistas de Espana"
hotels_df.loc[hotels_df.index[18555], "landmark"] = "2.0 miles to Albir Beach"

# %%
# Check countries again addresses for discrepancies
def func(x):
    return x.country not in x.address
hotels_df["discrepancy"] = hotels_df.apply(func, axis=1)

# %%
# Drop discrepancies
hotels_df = hotels_df[~hotels_df.discrepancy]

# %%
# Sanity Check
hotels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15592 entries, 0 to 19819
# Data columns (total 11 columns):
# city                 15592 non-null object
# country              15592 non-null object
# hotel_name           15592 non-null object
# rating               15592 non-null object
# address              15592 non-null object
# popularity_rating    15592 non-null object
# locality             15592 non-null object
# price                15592 non-null object
# landmark             15592 non-null object
# URL                  15592 non-null object
# discrepancy          15592 non-null bool
# dtypes: bool(1), object(10)
# memory usage: 1.3+ MB

# %%
# Replace na values with np.nan
hotels_df["price"] = hotels_df["price"].replace("na", np.nan)

# %%
# Convert price to int
f = lambda x: float(x) if x != np.nan else np.nan
hotels_df["price"] = hotels_df["price"].map(f)

# %%
# Replace na values with np.nan
hotels_df["rating"] = hotels_df["rating"].replace("na", np.nan)

# Convert rating to float
hotels_df["rating"] = hotels_df["rating"].map(f)

# %%
# Replace na values with np.nan
hotels_df["popularity_rating"] = hotels_df["popularity_rating"].replace("na", np.nan)

# Convert rating to float
hotels_df["popularity_rating"] = hotels_df["popularity_rating"].map(f)

# %%
# Check for null values again
hotels_df.isna().sum()
# Out:
# city                    0
# country                 0
# hotel_name              0
# rating               4316
# address                 0
# popularity_rating    4316
# locality                0
# price                9152
# landmark                0
# URL                     0
# discrepancy             0
# dtype: int64

# %%
# Convert all landmarks to strings
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: str(x))

# %%
# Convert all landmarks to lowercase
hotels_df["landmark"] = hotels_df["landmark"].apply(lambda x: x.lower())

# %%
# Split landmark
hotels_df["landmark"] = hotels_df["landmark"].str.split("\n")

# %%
hotels_df.describe()
# Out:
#              rating  popularity_rating        price
# count  11276.000000       11276.000000  6440.000000
# mean       4.162159         210.298865   131.239752
# std        0.592656         237.486363   106.724037
# min        1.000000           1.000000     3.000000
# 25%        4.000000          32.000000    71.000000
# 50%        4.000000         114.000000   103.000000
# 75%        4.500000         311.000000   154.000000
# max        5.000000         998.000000   974.000000

# %%
# Replace np.nan with values from .describe()
hotels_df["price"] = hotels_df["price"].replace(np.nan, 115)
hotels_df["rating"] = hotels_df["rating"].replace(np.nan, 4.0)
hotels_df["popularity_rating"] = hotels_df["popularity_rating"].replace(np.nan, 100)

# %%
# Check for null values again
hotels_df.isna().sum()
# Out:
# city                 0
# country              0
# hotel_name           0
# rating               0
# address              0
# popularity_rating    0
# locality             0
# price                0
# landmark             0
# URL                  0
# discrepancy          0
# dtype: int64

# %%
# Prepare city column

# Convert all cities to lowercase
hotels_df["city"] = hotels_df["city"].apply(lambda x: x.lower())

city_list = hotels_df["city"].tolist()

# Find set of unique cities and convert to a list
unique_cities = list(set(city_list))

# Create indexes for each city
city_index = {city: idx for idx, city in enumerate(unique_cities)}
index_city = {idx: city for city, idx in city_index.items()}

# %%
# Prepare country column

# Convert all countries to lowercase
hotels_df["country"] = hotels_df["country"].apply(lambda x: x.lower())

country_list = hotels_df["country"].tolist()

# Find set of unique countries and convert to a list
unique_countries = list(set(country_list))

# Create indexes for each property
country_index = {country: idx for idx, country in enumerate(unique_countries)}
index_country = {idx: country for country, idx in country_index.items()}

# %%
# Prepare hotel_name column

# Convert all hotels to lowercase
hotels_df["hotel_name"] = hotels_df["hotel_name"].apply(lambda x: x.lower())

# Create hotel names list
hotels_list = hotels_df["hotel_name"].tolist()

# Unique hotels
unique_hotels = list(set(hotels_list))

# Create indexes for each hotel
hotel_index = {hotel: idx for idx, hotel in enumerate(unique_hotels)}
index_hotel = {idx: hotel for hotel, idx in hotel_index.items()}

# %%
# Create ratings list
rating_list = hotels_df["rating"].tolist()

# Find set of unique ratings and convert to a list
unique_ratings = list(set(rating_list))

# Create indexes for each rating
rating_index = {rating: idx for idx, rating in enumerate(unique_ratings)}
index_rating = {idx: rating for rating, idx in rating_index.items()}

# %%
# Create popularity ratings list
popularity_list = hotels_df["popularity_rating"].tolist()

# Find set of unique ratings and convert to a list
unique_popularity = list(set(popularity_list))

# Create indexes for each rating
popularity_index = {popularity: idx for idx, popularity in enumerate(unique_popularity)}
index_popularity = {idx: popularity for popularity, idx in popularity_index.items()}

# %%
# Prepare locality column

# Convert all hotels to lowercase
hotels_df["locality"] = hotels_df["locality"].apply(lambda x: x.lower())

# Create hotel names list
locality_list = hotels_df["locality"].tolist()
unique_localities = list(set(locality_list))

# Create indexes for each hotel
locality_index = {locality: idx for idx, locality in enumerate(unique_localities)}
index_locality = {idx: locality for locality, idx in locality_index.items()}

# %%
# Create price list
price_list = hotels_df["price"].tolist()

# Unique prices
unique_prices = list(set(price_list))

# Create indexes for each price
price_index = {price: idx for idx, price in enumerate(unique_prices)}
index_price = {idx: price for price, idx in price_index.items()}

# %%
# Prepare locality column

# Create hotel names list
landmark_list = hotels_df["landmark"].tolist()

# Find set of unique properties and convert to a list
unique_landmarks = list(chain(*[list(set(landmarks)) for landmarks in landmark_list]))
unique_landmarks = list(set(unique_landmarks))

# Create indexes for each hotel
landmark_index = {landmark: idx for idx, landmark in enumerate(unique_landmarks)}
index_landmark = {idx: landmark for landmark, idx in landmark_index.items()}

# %%
# Build tuples to train embedding neural network
hotel_tuples = []

# Iterate through each row of dataframe
for index, row in hotels_df.iterrows():
    # Iterate through the properties in the item
    hotel_tuples.extend((city_index[hotels_df.at[index, "city"]], country_index[hotels_df.at[index, "country"]],
                         hotel_index[hotels_df.at[index, "hotel_name"]], rating_index[hotels_df.at[index, "rating"]],
                         popularity_index[hotels_df.at[index, "popularity_rating"]], 
                         locality_index[hotels_df.at[index, "locality"]], 
                         price_index[hotels_df.at[index, "price"]], landmark_index[landmark]) for landmark 
                        in hotels_df.at[index, "landmark"] if landmark.lower() in unique_landmarks)

# %%
# Generator for training samples
def generate_batch(tuples, n_positive = 75, negative_ratio = 2.0):
    
    pairs_set = set(tuples)
    
    batch_size = n_positive * (1 + negative_ratio)
    batch = np.zeros((batch_size, 9))
    
    # Label for negative examples
    neg_label = 0
    
    # This creates a generator
    while True:
        # randomly choose positive examples
        for idx, (city_id, country_id, hotel_id, rating_id, popularity_id, locality_id, price_id, landmark_id) in enumerate(random.sample(tuples, n_positive)):
            batch[idx, :] = (city_id, country_id, hotel_id, rating_id, popularity_id, locality_id, price_id, landmark_id, 1)

        # Increment idx by 1
        idx += 1
        
        # Add negative examples until reach batch size
        while idx < batch_size:
            
            # random selection
            random_city = random.randrange(len(unique_cities))
            random_country = random.randrange(len(unique_countries))
            random_hotel = random.randrange(len(unique_hotels))
            random_rating = random.randrange(len(unique_ratings))
            random_popularity = random.randrange(len(unique_popularity))
            random_locality = random.randrange(len(unique_localities))
            random_price = random.randrange(len(unique_prices))
            random_landmark = random.randrange(len(unique_landmarks))
            
            # Check to make sure this is not a positive example
            if (random_city, random_country, random_hotel, random_rating, random_popularity, random_locality,
               random_price, random_landmark) not in pairs_set:
                
                # Add to batch and increment index
                batch[idx, :] = (random_city, random_country, random_hotel, random_rating, random_popularity, random_locality,
                                   random_price, random_landmark, neg_label)
                idx += 1
                
        # Make sure to shuffle order
        np.random.shuffle(batch)
        yield {"city": batch[:, 0], "country": batch[:, 1], "hotel": batch[:, 2], 
               "rating": batch[:, 3], "popularity": batch[:, 4], "locality": batch[:, 5], 
               "price": batch[:, 6], "landmark": batch[:, 7]}, batch[:, 8]

# %%
# Properties embedding model
def hotel_embeddings(embedding_size = 50):
    
    # Inputs are one-dimensional
    city = Input(name = "city", shape = [1])
    country = Input(name = "country", shape = [1])
    hotel = Input(name = "hotel", shape = [1])
    rating = Input(name = "rating", shape = [1])
    popularity = Input(name = "popularity", shape = [1])
    locality = Input(name = "locality", shape = [1])
    price = Input(name = "price", shape = [1])
    landmark = Input(name = "landmark", shape = [1])
    
    # Embedding the city
    city_embedding = Embedding(name = "city_embedding", input_dim = len(city_index), 
                              output_dim = embedding_size)(city)
    
    # Embedding the country
    country_embedding = Embedding(name = "country_embedding", input_dim = len(country_index),
                                  output_dim = embedding_size)(country)
    
    # Embedding the hotel
    hotel_embedding = Embedding(name = "hotel_embedding", input_dim = len(hotel_index),
                                  output_dim = embedding_size)(hotel)
    
    # Embedding the rating
    rating_embedding = Embedding(name = "rating_embedding", input_dim = len(rating_index),
                                  output_dim = embedding_size)(rating)
    
    # Embedding the popularity
    popularity_embedding = Embedding(name = "popularity_embedding", input_dim = len(popularity_index),
                                  output_dim = embedding_size)(popularity)    
    
    # Embedding the locality
    locality_embedding = Embedding(name = "locality_embedding", input_dim = len(locality_index),
                                  output_dim = embedding_size)(locality)
    
    # Embedding the price
    price_embedding = Embedding(name = "price_embedding", input_dim = len(price_index),
                                  output_dim = embedding_size)(price)
    
    # Embedding the landmark
    landmark_embedding = Embedding(name = "landmark_embedding", input_dim = len(landmark_index),
                                  output_dim = embedding_size)(landmark)
    
    
    # Merge the embeddings with multiplication 
    merged_one = Multiply(name = "interaction_one")([city_embedding, country_embedding])
    merged_two = Multiply(name = "interaction_two")([city_embedding, hotel_embedding])
    merged_three = Multiply(name = "interaction_three")([city_embedding, rating_embedding])
    merged_four = Multiply(name = "interaction_four")([city_embedding, locality_embedding])
    merged_five = Multiply(name = "interaction_five")([city_embedding, price_embedding])
    merged_six = Multiply(name = "interaction_six")([city_embedding, landmark_embedding])
    merged_seven = Multiply(name = "interaction_seven")([country_embedding, hotel_embedding])
    merged_eight = Multiply(name = "interaction_eight")([country_embedding, rating_embedding])
    merged_nine = Multiply(name = "interaction_nine")([country_embedding, locality_embedding])
    merged_ten = Multiply(name = "interaction_ten")([country_embedding, price_embedding])
    merged_eleven = Multiply(name = "interaction_eleven")([country_embedding, landmark_embedding])
    merged_twelve = Multiply(name = "interaction_twelve")([hotel_embedding, rating_embedding])  
    merged_thirteen = Multiply(name = "interaction_thirteen")([hotel_embedding, locality_embedding])  
    merged_fourteen = Multiply(name = "interaction_fourteen")([hotel_embedding, price_embedding])  
    merged_fifteen = Multiply(name = "interaction_fifteen")([hotel_embedding, landmark_embedding])  
    merged_sixteen = Multiply(name = "interaction_sixteen")([rating_embedding, locality_embedding])  
    merged_seventeen = Multiply(name = "interaction_seventeen")([rating_embedding, price_embedding])  
    merged_eighteen = Multiply(name = "interaction_eighteen")([rating_embedding, landmark_embedding])  
    merged_nineteen = Multiply(name = "interaction_nineteen")([locality_embedding, price_embedding])  
    merged_twenty = Multiply(name = "interaction_twenty")([locality_embedding, landmark_embedding])
    merged_twentyone = Multiply(name = "interaction_twentyone")([price_embedding, landmark_embedding])
    merged_twentytwo = Multiply(name = "interaction_twentytwo")([popularity_embedding, city_embedding])
    merged_twentythree = Multiply(name = "interaction_twentythree")([popularity_embedding, country_embedding])
    merged_twentyfour = Multiply(name = "interaction_twentyfour")([popularity_embedding, hotel_embedding])
    merged_twentyfive = Multiply(name = "interaction_twentyfive")([popularity_embedding, rating_embedding])
    merged_twentysix = Multiply(name = "interaction_twentysix")([popularity_embedding, locality_embedding])
    merged_twentyseven = Multiply(name = "interaction_twentyseven")([popularity_embedding, price_embedding])
    merged_twentyeight = Multiply(name = "interaction_twentyeight")([popularity_embedding, landmark_embedding])
    
    # GlobalMaxPool
    pooling_one = GlobalMaxPool1D(name = "pooling_one")(merged_one)
    pooling_two = GlobalMaxPool1D(name = "pooling_two")(merged_two)
    pooling_three = GlobalMaxPool1D(name = "pooling_three")(merged_three)
    pooling_four = GlobalMaxPool1D(name = "pooling_four")(merged_four)
    pooling_five = GlobalMaxPool1D(name = "pooling_five")(merged_five)
    pooling_six = GlobalMaxPool1D(name = "pooling_six")(merged_six)    
    pooling_seven = GlobalMaxPool1D(name = "pooling_seven")(merged_seven)
    pooling_eight = GlobalMaxPool1D(name = "pooling_eight")(merged_eight)   
    pooling_nine = GlobalMaxPool1D(name = "pooling_nine")(merged_nine)   
    pooling_ten = GlobalMaxPool1D(name = "pooling_ten")(merged_ten)    
    pooling_eleven = GlobalMaxPool1D(name = "pooling_eleven")(merged_eleven)    
    pooling_twelve = GlobalMaxPool1D(name = "pooling_twelve")(merged_twelve)  
    pooling_thirteen = GlobalMaxPool1D(name = "pooling_thirteen")(merged_thirteen)
    pooling_fourteen = GlobalMaxPool1D(name = "pooling_fourteen")(merged_fourteen)
    pooling_fifteen = GlobalMaxPool1D(name = "pooling_fifteen")(merged_fifteen)
    pooling_sixteen = GlobalMaxPool1D(name = "pooling_sixteen")(merged_sixteen)
    pooling_seventeen = GlobalMaxPool1D(name = "pooling_seventeen")(merged_seventeen)
    pooling_eighteen = GlobalMaxPool1D(name = "pooling_eighteen")(merged_eighteen)
    pooling_nineteen = GlobalMaxPool1D(name = "pooling_nineteen")(merged_nineteen)
    pooling_twenty = GlobalMaxPool1D(name = "pooling_twenty")(merged_twenty)
    pooling_twentyone = GlobalMaxPool1D(name = "pooling_twentyone")(merged_twentyone)
    pooling_twentytwo = GlobalMaxPool1D(name = "pooling_twentytwo")(merged_twentytwo)
    pooling_twentythree = GlobalMaxPool1D(name = "pooling_twentythree")(merged_twentythree)
    pooling_twentyfour = GlobalMaxPool1D(name = "pooling_twentyfour")(merged_twentyfour)
    pooling_twentyfive = GlobalMaxPool1D(name = "pooling_twentyfive")(merged_twentyfive)
    pooling_twentysix = GlobalMaxPool1D(name = "pooling_twentysix")(merged_twentysix)
    pooling_twentyseven = GlobalMaxPool1D(name = "pooling_twentyseven")(merged_twentyseven)
    pooling_twentyeight = GlobalMaxPool1D(name = "pooling_twentyeight")(merged_twentyeight)
    
    # Dot Product
    dot_1 = Dot(name = "dot_1", normalize = True, axes = -1)([pooling_one, pooling_two])
    dot_2 = Dot(name = "dot_2", normalize = True, axes = -1)([pooling_one, pooling_three])
    dot_3 = Dot(name = "dot_3", normalize = True, axes = -1)([pooling_one, pooling_four])
    dot_4 = Dot(name = "dot_4", normalize = True, axes = -1)([pooling_one, pooling_five])
    dot_5 = Dot(name = "dot_5", normalize = True, axes = -1)([pooling_one, pooling_six])
    dot_6 = Dot(name = "dot_6", normalize = True, axes = -1)([pooling_one, pooling_seven])
    dot_7 = Dot(name = "dot_7", normalize = True, axes = -1)([pooling_one, pooling_eight])
    dot_8 = Dot(name = "dot_8", normalize = True, axes = -1)([pooling_one, pooling_nine])
    dot_9 = Dot(name = "dot_9", normalize = True, axes = -1)([pooling_one, pooling_ten])
    dot_10 = Dot(name = "dot_10", normalize = True, axes = -1)([pooling_one, pooling_eleven])
    dot_11 = Dot(name = "dot_11", normalize = True, axes = -1)([pooling_one, pooling_twelve])
    dot_12 = Dot(name = "dot_12", normalize = True, axes = -1)([pooling_one, pooling_thirteen])
    dot_13 = Dot(name = "dot_13", normalize = True, axes = -1)([pooling_one, pooling_fourteen])
    dot_14 = Dot(name = "dot_14", normalize = True, axes = -1)([pooling_one, pooling_fifteen])
    dot_15 = Dot(name = "dot_15", normalize = True, axes = -1)([pooling_one, pooling_sixteen])
    dot_16 = Dot(name = "dot_16", normalize = True, axes = -1)([pooling_one, pooling_seventeen])
    dot_17 = Dot(name = "dot_17", normalize = True, axes = -1)([pooling_one, pooling_eighteen])
    dot_18 = Dot(name = "dot_18", normalize = True, axes = -1)([pooling_one, pooling_nineteen])
    dot_19 = Dot(name = "dot_19", normalize = True, axes = -1)([pooling_one, pooling_twenty])
    dot_20 = Dot(name = "dot_20", normalize = True, axes = -1)([pooling_one, pooling_twentyone])
    dot_21 = Dot(name = "dot_21", normalize = True, axes = -1)([pooling_one, pooling_twentytwo])
    dot_22 = Dot(name = "dot_22", normalize = True, axes = -1)([pooling_one, pooling_twentythree])
    dot_23 = Dot(name = "dot_23", normalize = True, axes = -1)([pooling_one, pooling_twentyfour])
    dot_24 = Dot(name = "dot_24", normalize = True, axes = -1)([pooling_one, pooling_twentyfive])    
    dot_25 = Dot(name = "dot_25", normalize = True, axes = -1)([pooling_one, pooling_twentysix])    
    dot_26 = Dot(name = "dot_26", normalize = True, axes = -1)([pooling_one, pooling_twentyseven])    
    dot_27 = Dot(name = "dot_27", normalize = True, axes = -1)([pooling_one, pooling_twentyeight])    
    dot_28 = Dot(name = "dot_28", normalize = True, axes = -1)([pooling_two, pooling_three])    
    dot_29 = Dot(name = "dot_29", normalize = True, axes = -1)([pooling_two, pooling_four])   
    dot_30 = Dot(name = "dot_30", normalize = True, axes = -1)([pooling_two, pooling_five])   
    dot_31 = Dot(name = "dot_31", normalize = True, axes = -1)([pooling_two, pooling_six])   
    dot_32 = Dot(name = "dot_32", normalize = True, axes = -1)([pooling_two, pooling_seven])   
    dot_33 = Dot(name = "dot_33", normalize = True, axes = -1)([pooling_two, pooling_eight])   
    dot_34 = Dot(name = "dot_34", normalize = True, axes = -1)([pooling_two, pooling_nine])   
    dot_35 = Dot(name = "dot_35", normalize = True, axes = -1)([pooling_two, pooling_ten])   
    dot_36 = Dot(name = "dot_36", normalize = True, axes = -1)([pooling_two, pooling_eleven])   
    dot_37 = Dot(name = "dot_37", normalize = True, axes = -1)([pooling_two, pooling_twelve])   
    dot_38 = Dot(name = "dot_38", normalize = True, axes = -1)([pooling_two, pooling_thirteen])   
    dot_39 = Dot(name = "dot_39", normalize = True, axes = -1)([pooling_two, pooling_fourteen])   
    dot_40 = Dot(name = "dot_40", normalize = True, axes = -1)([pooling_two, pooling_fifteen])   
    dot_41 = Dot(name = "dot_41", normalize = True, axes = -1)([pooling_two, pooling_sixteen])   
    dot_42 = Dot(name = "dot_42", normalize = True, axes = -1)([pooling_two, pooling_seventeen])   
    dot_43 = Dot(name = "dot_43", normalize = True, axes = -1)([pooling_two, pooling_eighteen]) 
    dot_44 = Dot(name = "dot_44", normalize = True, axes = -1)([pooling_two, pooling_nineteen]) 
    dot_45 = Dot(name = "dot_45", normalize = True, axes = -1)([pooling_two, pooling_twenty]) 
    dot_46 = Dot(name = "dot_46", normalize = True, axes = -1)([pooling_two, pooling_twentyone]) 
    dot_47 = Dot(name = "dot_47", normalize = True, axes = -1)([pooling_two, pooling_twentytwo]) 
    dot_48 = Dot(name = "dot_48", normalize = True, axes = -1)([pooling_two, pooling_twentythree]) 
    dot_49 = Dot(name = "dot_49", normalize = True, axes = -1)([pooling_two, pooling_twentyfour]) 
    dot_50 = Dot(name = "dot_50", normalize = True, axes = -1)([pooling_two, pooling_twentyfive]) 
    dot_51 = Dot(name = "dot_51", normalize = True, axes = -1)([pooling_two, pooling_twentysix]) 
    dot_52 = Dot(name = "dot_52", normalize = True, axes = -1)([pooling_two, pooling_twentyseven]) 
    dot_53 = Dot(name = "dot_53", normalize = True, axes = -1)([pooling_two, pooling_twentyeight]) 
    dot_54 = Dot(name = "dot_54", normalize = True, axes = -1)([pooling_three, pooling_four])    
    dot_55 = Dot(name = "dot_55", normalize = True, axes = -1)([pooling_three, pooling_five]) 
    dot_56 = Dot(name = "dot_56", normalize = True, axes = -1)([pooling_three, pooling_six]) 
    dot_57 = Dot(name = "dot_57", normalize = True, axes = -1)([pooling_three, pooling_seven]) 
    dot_58 = Dot(name = "dot_58", normalize = True, axes = -1)([pooling_three, pooling_eight]) 
    dot_59 = Dot(name = "dot_59", normalize = True, axes = -1)([pooling_three, pooling_nine]) 
    dot_60 = Dot(name = "dot_60", normalize = True, axes = -1)([pooling_three, pooling_ten]) 
    dot_61 = Dot(name = "dot_61", normalize = True, axes = -1)([pooling_three, pooling_eleven]) 
    dot_62 = Dot(name = "dot_62", normalize = True, axes = -1)([pooling_three, pooling_twelve]) 
    dot_63 = Dot(name = "dot_63", normalize = True, axes = -1)([pooling_three, pooling_thirteen]) 
    dot_64 = Dot(name = "dot_64", normalize = True, axes = -1)([pooling_three, pooling_fourteen]) 
    dot_65 = Dot(name = "dot_65", normalize = True, axes = -1)([pooling_three, pooling_fifteen]) 
    dot_66 = Dot(name = "dot_66", normalize = True, axes = -1)([pooling_three, pooling_sixteen]) 
    dot_67 = Dot(name = "dot_67", normalize = True, axes = -1)([pooling_three, pooling_seventeen]) 
    dot_68 = Dot(name = "dot_68", normalize = True, axes = -1)([pooling_three, pooling_eighteen]) 
    dot_69 = Dot(name = "dot_69", normalize = True, axes = -1)([pooling_three, pooling_nineteen]) 
    dot_70 = Dot(name = "dot_70", normalize = True, axes = -1)([pooling_three, pooling_twenty])
    dot_71 = Dot(name = "dot_71", normalize = True, axes = -1)([pooling_three, pooling_twentyone])
    dot_72 = Dot(name = "dot_72", normalize = True, axes = -1)([pooling_three, pooling_twentytwo])
    dot_73 = Dot(name = "dot_73", normalize = True, axes = -1)([pooling_three, pooling_twentythree])
    dot_74 = Dot(name = "dot_74", normalize = True, axes = -1)([pooling_three, pooling_twentyfour])
    dot_75 = Dot(name = "dot_75", normalize = True, axes = -1)([pooling_three, pooling_twentyfive])
    dot_76 = Dot(name = "dot_76", normalize = True, axes = -1)([pooling_three, pooling_twentysix])
    dot_77 = Dot(name = "dot_77", normalize = True, axes = -1)([pooling_three, pooling_twentyseven])
    dot_78 = Dot(name = "dot_78", normalize = True, axes = -1)([pooling_three, pooling_twentyeight])
    dot_79 = Dot(name = "dot_79", normalize = True, axes = -1)([pooling_four, pooling_five])
    dot_80 = Dot(name = "dot_80", normalize = True, axes = -1)([pooling_four, pooling_six])
    dot_81 = Dot(name = "dot_81", normalize = True, axes = -1)([pooling_four, pooling_seven])
    dot_82 = Dot(name = "dot_82", normalize = True, axes = -1)([pooling_four, pooling_eight])
    dot_83 = Dot(name = "dot_83", normalize = True, axes = -1)([pooling_four, pooling_nine])
    dot_84 = Dot(name = "dot_84", normalize = True, axes = -1)([pooling_four, pooling_ten])
    dot_85 = Dot(name = "dot_85", normalize = True, axes = -1)([pooling_four, pooling_eleven])
    dot_86 = Dot(name = "dot_86", normalize = True, axes = -1)([pooling_four, pooling_twelve])
    dot_87 = Dot(name = "dot_87", normalize = True, axes = -1)([pooling_four, pooling_thirteen])
    dot_88 = Dot(name = "dot_88", normalize = True, axes = -1)([pooling_four, pooling_fourteen])
    dot_89 = Dot(name = "dot_89", normalize = True, axes = -1)([pooling_four, pooling_fifteen])
    dot_90 = Dot(name = "dot_90", normalize = True, axes = -1)([pooling_four, pooling_sixteen])
    dot_91 = Dot(name = "dot_91", normalize = True, axes = -1)([pooling_four, pooling_seventeen])
    dot_92 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_eighteen])
    dot_93 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_nineteen])
    dot_94 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twenty])
    dot_95 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentyone])
    dot_96 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentytwo])
    dot_97 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentythree])
    dot_98 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentyfour])
    dot_99 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentyfive])
    dot_100 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentysix])
    dot_101 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentyseven])
    dot_102 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_four, pooling_twentyeight])
    dot_80 = Dot(name = "dot_80", normalize = True, axes = -1)([pooling_five, pooling_six])
    dot_81 = Dot(name = "dot_81", normalize = True, axes = -1)([pooling_five, pooling_seven])
    dot_82 = Dot(name = "dot_82", normalize = True, axes = -1)([pooling_five, pooling_eight])
    dot_83 = Dot(name = "dot_83", normalize = True, axes = -1)([pooling_five, pooling_nine])
    dot_84 = Dot(name = "dot_84", normalize = True, axes = -1)([pooling_five, pooling_ten])
    dot_85 = Dot(name = "dot_85", normalize = True, axes = -1)([pooling_five, pooling_eleven])
    dot_86 = Dot(name = "dot_86", normalize = True, axes = -1)([pooling_five, pooling_twelve])
    dot_87 = Dot(name = "dot_87", normalize = True, axes = -1)([pooling_five, pooling_thirteen])
    dot_88 = Dot(name = "dot_88", normalize = True, axes = -1)([pooling_five, pooling_fourteen])
    dot_89 = Dot(name = "dot_89", normalize = True, axes = -1)([pooling_five, pooling_fifteen])
    dot_90 = Dot(name = "dot_90", normalize = True, axes = -1)([pooling_five, pooling_sixteen])
    dot_91 = Dot(name = "dot_91", normalize = True, axes = -1)([pooling_five, pooling_seventeen])
    dot_92 = Dot(name = "dot_92", normalize = True, axes = -1)([pooling_five, pooling_eighteen])
    dot_93 = Dot(name = "dot_93", normalize = True, axes = -1)([pooling_five, pooling_nineteen])
    dot_94 = Dot(name = "dot_94", normalize = True, axes = -1)([pooling_five, pooling_twenty])
    dot_95 = Dot(name = "dot_95", normalize = True, axes = -1)([pooling_five, pooling_twentyone])
    dot_96 = Dot(name = "dot_96", normalize = True, axes = -1)([pooling_five, pooling_twentytwo])
    dot_97 = Dot(name = "dot_97", normalize = True, axes = -1)([pooling_five, pooling_twentythree])
    dot_98 = Dot(name = "dot_98", normalize = True, axes = -1)([pooling_five, pooling_twentyfour])
    dot_99 = Dot(name = "dot_99", normalize = True, axes = -1)([pooling_five, pooling_twentyfive])
    dot_100 = Dot(name = "dot_100", normalize = True, axes = -1)([pooling_five, pooling_twentysix])
    dot_101 = Dot(name = "dot_101", normalize = True, axes = -1)([pooling_five, pooling_twentyseven])
    dot_102 = Dot(name = "dot_102", normalize = True, axes = -1)([pooling_five, pooling_twentyeight])
    dot_103 = Dot(name = "dot_103", normalize = True, axes = -1)([pooling_six, pooling_seven])
    dot_104 = Dot(name = "dot_104", normalize = True, axes = -1)([pooling_six, pooling_eight])
    dot_105 = Dot(name = "dot_105", normalize = True, axes = -1)([pooling_six, pooling_nine])
    dot_106 = Dot(name = "dot_106", normalize = True, axes = -1)([pooling_six, pooling_ten])
    dot_107 = Dot(name = "dot_107", normalize = True, axes = -1)([pooling_six, pooling_eleven])
    dot_108 = Dot(name = "dot_108", normalize = True, axes = -1)([pooling_six, pooling_twelve])
    dot_109 = Dot(name = "dot_109", normalize = True, axes = -1)([pooling_six, pooling_thirteen])
    dot_110 = Dot(name = "dot_110", normalize = True, axes = -1)([pooling_six, pooling_fourteen])
    dot_111 = Dot(name = "dot_111", normalize = True, axes = -1)([pooling_six, pooling_fifteen])
    dot_112 = Dot(name = "dot_112", normalize = True, axes = -1)([pooling_six, pooling_sixteen])
    dot_113 = Dot(name = "dot_113", normalize = True, axes = -1)([pooling_six, pooling_seventeen])
    dot_114 = Dot(name = "dot_114", normalize = True, axes = -1)([pooling_six, pooling_eighteen])
    dot_115 = Dot(name = "dot_115", normalize = True, axes = -1)([pooling_six, pooling_nineteen])
    dot_116 = Dot(name = "dot_116", normalize = True, axes = -1)([pooling_six, pooling_twenty])
    dot_117 = Dot(name = "dot_117", normalize = True, axes = -1)([pooling_six, pooling_twentyone])
    dot_118 = Dot(name = "dot_118", normalize = True, axes = -1)([pooling_six, pooling_twentytwo])
    dot_119 = Dot(name = "dot_119", normalize = True, axes = -1)([pooling_six, pooling_twentythree])
    dot_120 = Dot(name = "dot_120", normalize = True, axes = -1)([pooling_six, pooling_twentyfour])
    dot_121 = Dot(name = "dot_121", normalize = True, axes = -1)([pooling_six, pooling_twentyfive])
    dot_122 = Dot(name = "dot_122", normalize = True, axes = -1)([pooling_six, pooling_twentysix])
    dot_123 = Dot(name = "dot_123", normalize = True, axes = -1)([pooling_six, pooling_twentyseven])
    dot_124 = Dot(name = "dot_124", normalize = True, axes = -1)([pooling_six, pooling_twentyeight])
    dot_125 = Dot(name = "dot_125", normalize = True, axes = -1)([pooling_seven, pooling_eight])
    dot_126 = Dot(name = "dot_126", normalize = True, axes = -1)([pooling_seven, pooling_nine])
    dot_127 = Dot(name = "dot_127", normalize = True, axes = -1)([pooling_seven, pooling_ten])
    dot_128 = Dot(name = "dot_128", normalize = True, axes = -1)([pooling_seven, pooling_eleven])
    dot_129 = Dot(name = "dot_129", normalize = True, axes = -1)([pooling_seven, pooling_twelve])
    dot_130 = Dot(name = "dot_130", normalize = True, axes = -1)([pooling_seven, pooling_thirteen])
    dot_131 = Dot(name = "dot_131", normalize = True, axes = -1)([pooling_seven, pooling_fourteen])
    dot_132 = Dot(name = "dot_132", normalize = True, axes = -1)([pooling_seven, pooling_fifteen])
    dot_133 = Dot(name = "dot_133", normalize = True, axes = -1)([pooling_seven, pooling_sixteen])
    dot_134 = Dot(name = "dot_134", normalize = True, axes = -1)([pooling_seven, pooling_seventeen])
    dot_135 = Dot(name = "dot_135", normalize = True, axes = -1)([pooling_seven, pooling_eighteen])
    dot_136 = Dot(name = "dot_136", normalize = True, axes = -1)([pooling_seven, pooling_nineteen])
    dot_137 = Dot(name = "dot_137", normalize = True, axes = -1)([pooling_seven, pooling_twenty])
    dot_138 = Dot(name = "dot_138", normalize = True, axes = -1)([pooling_seven, pooling_twentyone])
    dot_139 = Dot(name = "dot_139", normalize = True, axes = -1)([pooling_seven, pooling_twentytwo])
    dot_140 = Dot(name = "dot_140", normalize = True, axes = -1)([pooling_seven, pooling_twentythree])
    dot_141 = Dot(name = "dot_141", normalize = True, axes = -1)([pooling_seven, pooling_twentyfour])
    dot_142 = Dot(name = "dot_142", normalize = True, axes = -1)([pooling_seven, pooling_twentyfive])
    dot_143 = Dot(name = "dot_143", normalize = True, axes = -1)([pooling_seven, pooling_twentysix])
    dot_144 = Dot(name = "dot_144", normalize = True, axes = -1)([pooling_seven, pooling_twentyseven])
    dot_145 = Dot(name = "dot_145", normalize = True, axes = -1)([pooling_seven, pooling_twentyeight])
    dot_146 = Dot(name = "dot_146", normalize = True, axes = -1)([pooling_eight, pooling_nine])
    dot_147 = Dot(name = "dot_147", normalize = True, axes = -1)([pooling_eight, pooling_ten])
    dot_148 = Dot(name = "dot_148", normalize = True, axes = -1)([pooling_eight, pooling_eleven])
    dot_149 = Dot(name = "dot_149", normalize = True, axes = -1)([pooling_eight, pooling_twelve])
    dot_150 = Dot(name = "dot_150", normalize = True, axes = -1)([pooling_eight, pooling_thirteen])
    dot_151 = Dot(name = "dot_151", normalize = True, axes = -1)([pooling_eight, pooling_fourteen])
    dot_152 = Dot(name = "dot_152", normalize = True, axes = -1)([pooling_eight, pooling_fifteen])
    dot_153 = Dot(name = "dot_153", normalize = True, axes = -1)([pooling_eight, pooling_sixteen])
    dot_154 = Dot(name = "dot_154", normalize = True, axes = -1)([pooling_eight, pooling_seventeen])
    dot_155 = Dot(name = "dot_155", normalize = True, axes = -1)([pooling_eight, pooling_eighteen])
    dot_156 = Dot(name = "dot_156", normalize = True, axes = -1)([pooling_eight, pooling_nineteen])
    dot_157 = Dot(name = "dot_157", normalize = True, axes = -1)([pooling_eight, pooling_twenty])
    dot_158 = Dot(name = "dot_158", normalize = True, axes = -1)([pooling_eight, pooling_twentyone])
    dot_159 = Dot(name = "dot_159", normalize = True, axes = -1)([pooling_eight, pooling_twentytwo])
    dot_160 = Dot(name = "dot_160", normalize = True, axes = -1)([pooling_eight, pooling_twentythree])
    dot_161 = Dot(name = "dot_161", normalize = True, axes = -1)([pooling_eight, pooling_twentyfour])
    dot_162 = Dot(name = "dot_162", normalize = True, axes = -1)([pooling_eight, pooling_twentyfive])
    dot_163 = Dot(name = "dot_163", normalize = True, axes = -1)([pooling_eight, pooling_twentysix])
    dot_164 = Dot(name = "dot_164", normalize = True, axes = -1)([pooling_eight, pooling_twentyseven])
    dot_165 = Dot(name = "dot_165", normalize = True, axes = -1)([pooling_eight, pooling_twentyeight])
    dot_167 = Dot(name = "dot_167", normalize = True, axes = -1)([pooling_nine, pooling_ten])
    dot_168 = Dot(name = "dot_168", normalize = True, axes = -1)([pooling_nine, pooling_eleven])
    dot_169 = Dot(name = "dot_169", normalize = True, axes = -1)([pooling_nine, pooling_twelve])
    dot_170 = Dot(name = "dot_170", normalize = True, axes = -1)([pooling_nine, pooling_thirteen])
    dot_171 = Dot(name = "dot_171", normalize = True, axes = -1)([pooling_nine, pooling_fourteen])
    dot_172 = Dot(name = "dot_172", normalize = True, axes = -1)([pooling_nine, pooling_fifteen])
    dot_173 = Dot(name = "dot_173", normalize = True, axes = -1)([pooling_nine, pooling_sixteen])
    dot_174 = Dot(name = "dot_174", normalize = True, axes = -1)([pooling_nine, pooling_seventeen])
    dot_175 = Dot(name = "dot_175", normalize = True, axes = -1)([pooling_nine, pooling_eighteen])
    dot_176 = Dot(name = "dot_176", normalize = True, axes = -1)([pooling_nine, pooling_nineteen])
    dot_177 = Dot(name = "dot_177", normalize = True, axes = -1)([pooling_nine, pooling_twenty])
    dot_178 = Dot(name = "dot_178", normalize = True, axes = -1)([pooling_nine, pooling_twentyone])
    dot_179 = Dot(name = "dot_179", normalize = True, axes = -1)([pooling_nine, pooling_twentytwo])
    dot_180 = Dot(name = "dot_180", normalize = True, axes = -1)([pooling_nine, pooling_twentythree])
    dot_181 = Dot(name = "dot_181", normalize = True, axes = -1)([pooling_nine, pooling_twentyfour])
    dot_182 = Dot(name = "dot_182", normalize = True, axes = -1)([pooling_nine, pooling_twentyfive])
    dot_183 = Dot(name = "dot_183", normalize = True, axes = -1)([pooling_nine, pooling_twentysix])
    dot_184 = Dot(name = "dot_184", normalize = True, axes = -1)([pooling_nine, pooling_twentyseven])
    dot_185 = Dot(name = "dot_185", normalize = True, axes = -1)([pooling_nine, pooling_twentyeight])
    dot_187 = Dot(name = "dot_187", normalize = True, axes = -1)([pooling_ten, pooling_eleven])
    dot_188 = Dot(name = "dot_188", normalize = True, axes = -1)([pooling_ten, pooling_twelve])
    dot_189 = Dot(name = "dot_189", normalize = True, axes = -1)([pooling_ten, pooling_thirteen])
    dot_190 = Dot(name = "dot_190", normalize = True, axes = -1)([pooling_ten, pooling_fourteen])
    dot_191 = Dot(name = "dot_191", normalize = True, axes = -1)([pooling_ten, pooling_fifteen])
    dot_192 = Dot(name = "dot_192", normalize = True, axes = -1)([pooling_ten, pooling_sixteen])
    dot_193 = Dot(name = "dot_193", normalize = True, axes = -1)([pooling_ten, pooling_seventeen])
    dot_194 = Dot(name = "dot_194", normalize = True, axes = -1)([pooling_ten, pooling_eighteen])
    dot_195 = Dot(name = "dot_195", normalize = True, axes = -1)([pooling_ten, pooling_nineteen])
    dot_196 = Dot(name = "dot_196", normalize = True, axes = -1)([pooling_ten, pooling_twenty])
    dot_197 = Dot(name = "dot_197", normalize = True, axes = -1)([pooling_ten, pooling_twentyone])
    dot_198 = Dot(name = "dot_198", normalize = True, axes = -1)([pooling_ten, pooling_twentytwo])
    dot_199 = Dot(name = "dot_199", normalize = True, axes = -1)([pooling_ten, pooling_twentythree])
    dot_200 = Dot(name = "dot_200", normalize = True, axes = -1)([pooling_ten, pooling_twentyfour])
    dot_201 = Dot(name = "dot_201", normalize = True, axes = -1)([pooling_ten, pooling_twentyfive])
    dot_202 = Dot(name = "dot_202", normalize = True, axes = -1)([pooling_ten, pooling_twentysix])
    dot_203 = Dot(name = "dot_203", normalize = True, axes = -1)([pooling_ten, pooling_twentyseven])
    dot_204 = Dot(name = "dot_204", normalize = True, axes = -1)([pooling_ten, pooling_twentyeight])
    dot_206 = Dot(name = "dot_206", normalize = True, axes = -1)([pooling_eleven, pooling_twelve])
    dot_207 = Dot(name = "dot_207", normalize = True, axes = -1)([pooling_eleven, pooling_thirteen])
    dot_208 = Dot(name = "dot_208", normalize = True, axes = -1)([pooling_eleven, pooling_fourteen])
    dot_209 = Dot(name = "dot_209", normalize = True, axes = -1)([pooling_eleven, pooling_fifteen])
    dot_210 = Dot(name = "dot_210", normalize = True, axes = -1)([pooling_eleven, pooling_sixteen])
    dot_211 = Dot(name = "dot_211", normalize = True, axes = -1)([pooling_eleven, pooling_seventeen])
    dot_212 = Dot(name = "dot_212", normalize = True, axes = -1)([pooling_eleven, pooling_eighteen])
    dot_213 = Dot(name = "dot_213", normalize = True, axes = -1)([pooling_eleven, pooling_nineteen])
    dot_214 = Dot(name = "dot_214", normalize = True, axes = -1)([pooling_eleven, pooling_twenty])
    dot_215 = Dot(name = "dot_215", normalize = True, axes = -1)([pooling_eleven, pooling_twentyone])
    dot_216 = Dot(name = "dot_216", normalize = True, axes = -1)([pooling_eleven, pooling_twentytwo])
    dot_217 = Dot(name = "dot_217", normalize = True, axes = -1)([pooling_eleven, pooling_twentythree])
    dot_218 = Dot(name = "dot_218", normalize = True, axes = -1)([pooling_eleven, pooling_twentyfour])
    dot_219 = Dot(name = "dot_219", normalize = True, axes = -1)([pooling_eleven, pooling_twentyfive])
    dot_220 = Dot(name = "dot_220", normalize = True, axes = -1)([pooling_eleven, pooling_twentysix])
    dot_221 = Dot(name = "dot_221", normalize = True, axes = -1)([pooling_eleven, pooling_twentyseven])
    dot_222 = Dot(name = "dot_222", normalize = True, axes = -1)([pooling_eleven, pooling_twentyeight])   
    dot_224 = Dot(name = "dot_224", normalize = True, axes = -1)([pooling_twelve, pooling_thirteen])
    dot_225 = Dot(name = "dot_225", normalize = True, axes = -1)([pooling_twelve, pooling_fourteen])
    dot_226 = Dot(name = "dot_226", normalize = True, axes = -1)([pooling_twelve, pooling_fifteen])
    dot_227 = Dot(name = "dot_227", normalize = True, axes = -1)([pooling_twelve, pooling_sixteen])
    dot_228 = Dot(name = "dot_228", normalize = True, axes = -1)([pooling_twelve, pooling_seventeen])
    dot_229 = Dot(name = "dot_229", normalize = True, axes = -1)([pooling_twelve, pooling_eighteen])
    dot_230 = Dot(name = "dot_230", normalize = True, axes = -1)([pooling_twelve, pooling_nineteen])
    dot_231 = Dot(name = "dot_231", normalize = True, axes = -1)([pooling_twelve, pooling_twenty])
    dot_232 = Dot(name = "dot_232", normalize = True, axes = -1)([pooling_twelve, pooling_twentyone])
    dot_233 = Dot(name = "dot_233", normalize = True, axes = -1)([pooling_twelve, pooling_twentytwo])
    dot_234 = Dot(name = "dot_234", normalize = True, axes = -1)([pooling_twelve, pooling_twentythree])
    dot_235 = Dot(name = "dot_235", normalize = True, axes = -1)([pooling_twelve, pooling_twentyfour])
    dot_236 = Dot(name = "dot_236", normalize = True, axes = -1)([pooling_twelve, pooling_twentyfive])
    dot_237 = Dot(name = "dot_237", normalize = True, axes = -1)([pooling_twelve, pooling_twentysix])
    dot_238 = Dot(name = "dot_238", normalize = True, axes = -1)([pooling_twelve, pooling_twentyseven])
    dot_239 = Dot(name = "dot_239", normalize = True, axes = -1)([pooling_twelve, pooling_twentyeight])    
    dot_241 = Dot(name = "dot_241", normalize = True, axes = -1)([pooling_thirteen, pooling_fourteen])
    dot_242 = Dot(name = "dot_242", normalize = True, axes = -1)([pooling_thirteen, pooling_fifteen])
    dot_243 = Dot(name = "dot_243", normalize = True, axes = -1)([pooling_thirteen, pooling_sixteen])
    dot_244 = Dot(name = "dot_244", normalize = True, axes = -1)([pooling_thirteen, pooling_seventeen])
    dot_245 = Dot(name = "dot_245", normalize = True, axes = -1)([pooling_thirteen, pooling_eighteen])
    dot_246 = Dot(name = "dot_246", normalize = True, axes = -1)([pooling_thirteen, pooling_nineteen])
    dot_247 = Dot(name = "dot_247", normalize = True, axes = -1)([pooling_thirteen, pooling_twenty])
    dot_248 = Dot(name = "dot_248", normalize = True, axes = -1)([pooling_thirteen, pooling_twentyone])
    dot_249 = Dot(name = "dot_249", normalize = True, axes = -1)([pooling_thirteen, pooling_twentytwo])
    dot_250 = Dot(name = "dot_250", normalize = True, axes = -1)([pooling_thirteen, pooling_twentythree])
    dot_251 = Dot(name = "dot_251", normalize = True, axes = -1)([pooling_thirteen, pooling_twentyfour])
    dot_252 = Dot(name = "dot_252", normalize = True, axes = -1)([pooling_thirteen, pooling_twentyfive])
    dot_253 = Dot(name = "dot_253", normalize = True, axes = -1)([pooling_thirteen, pooling_twentysix])
    dot_254 = Dot(name = "dot_254", normalize = True, axes = -1)([pooling_thirteen, pooling_twentyseven])
    dot_255 = Dot(name = "dot_255", normalize = True, axes = -1)([pooling_thirteen, pooling_twentyeight]) 
    dot_257 = Dot(name = "dot_257", normalize = True, axes = -1)([pooling_fourteen, pooling_fifteen])
    dot_258 = Dot(name = "dot_258", normalize = True, axes = -1)([pooling_fourteen, pooling_sixteen])
    dot_259 = Dot(name = "dot_259", normalize = True, axes = -1)([pooling_fourteen, pooling_seventeen])
    dot_260 = Dot(name = "dot_260", normalize = True, axes = -1)([pooling_fourteen, pooling_eighteen])
    dot_261 = Dot(name = "dot_261", normalize = True, axes = -1)([pooling_fourteen, pooling_nineteen])
    dot_262 = Dot(name = "dot_262", normalize = True, axes = -1)([pooling_fourteen, pooling_twenty])
    dot_263 = Dot(name = "dot_263", normalize = True, axes = -1)([pooling_fourteen, pooling_twentyone])
    dot_264 = Dot(name = "dot_264", normalize = True, axes = -1)([pooling_fourteen, pooling_twentytwo])
    dot_265 = Dot(name = "dot_265", normalize = True, axes = -1)([pooling_fourteen, pooling_twentythree])
    dot_266 = Dot(name = "dot_266", normalize = True, axes = -1)([pooling_fourteen, pooling_twentyfour])
    dot_267 = Dot(name = "dot_267", normalize = True, axes = -1)([pooling_fourteen, pooling_twentyfive])
    dot_268 = Dot(name = "dot_268", normalize = True, axes = -1)([pooling_fourteen, pooling_twentysix])
    dot_269 = Dot(name = "dot_269", normalize = True, axes = -1)([pooling_fourteen, pooling_twentyseven])
    dot_270 = Dot(name = "dot_270", normalize = True, axes = -1)([pooling_fourteen, pooling_twentyeight])
    dot_272 = Dot(name = "dot_272", normalize = True, axes = -1)([pooling_fifteen, pooling_sixteen])
    dot_273 = Dot(name = "dot_273", normalize = True, axes = -1)([pooling_fifteen, pooling_seventeen])
    dot_274 = Dot(name = "dot_274", normalize = True, axes = -1)([pooling_fifteen, pooling_eighteen])
    dot_275 = Dot(name = "dot_275", normalize = True, axes = -1)([pooling_fifteen, pooling_nineteen])
    dot_276 = Dot(name = "dot_276", normalize = True, axes = -1)([pooling_fifteen, pooling_twenty])
    dot_277 = Dot(name = "dot_277", normalize = True, axes = -1)([pooling_fifteen, pooling_twentyone])
    dot_278 = Dot(name = "dot_278", normalize = True, axes = -1)([pooling_fifteen, pooling_twentytwo])
    dot_279 = Dot(name = "dot_279", normalize = True, axes = -1)([pooling_fifteen, pooling_twentythree])
    dot_280 = Dot(name = "dot_280", normalize = True, axes = -1)([pooling_fifteen, pooling_twentyfour])
    dot_281 = Dot(name = "dot_281", normalize = True, axes = -1)([pooling_fifteen, pooling_twentyfive])
    dot_282 = Dot(name = "dot_282", normalize = True, axes = -1)([pooling_fifteen, pooling_twentysix])
    dot_283 = Dot(name = "dot_283", normalize = True, axes = -1)([pooling_fifteen, pooling_twentyseven])
    dot_284 = Dot(name = "dot_284", normalize = True, axes = -1)([pooling_fifteen, pooling_twentyeight])
    dot_286 = Dot(name = "dot_286", normalize = True, axes = -1)([pooling_sixteen, pooling_seventeen])
    dot_287 = Dot(name = "dot_287", normalize = True, axes = -1)([pooling_sixteen, pooling_eighteen])
    dot_288 = Dot(name = "dot_288", normalize = True, axes = -1)([pooling_sixteen, pooling_nineteen])
    dot_289 = Dot(name = "dot_289", normalize = True, axes = -1)([pooling_sixteen, pooling_twenty])
    dot_290 = Dot(name = "dot_290", normalize = True, axes = -1)([pooling_sixteen, pooling_twentyone])
    dot_291 = Dot(name = "dot_291", normalize = True, axes = -1)([pooling_sixteen, pooling_twentytwo])
    dot_292 = Dot(name = "dot_292", normalize = True, axes = -1)([pooling_sixteen, pooling_twentythree])
    dot_293 = Dot(name = "dot_293", normalize = True, axes = -1)([pooling_sixteen, pooling_twentyfour])
    dot_294 = Dot(name = "dot_294", normalize = True, axes = -1)([pooling_sixteen, pooling_twentyfive])
    dot_295 = Dot(name = "dot_295", normalize = True, axes = -1)([pooling_sixteen, pooling_twentysix])
    dot_296 = Dot(name = "dot_296", normalize = True, axes = -1)([pooling_sixteen, pooling_twentyseven])
    dot_297 = Dot(name = "dot_297", normalize = True, axes = -1)([pooling_sixteen, pooling_twentyeight])
    dot_299 = Dot(name = "dot_299", normalize = True, axes = -1)([pooling_seventeen, pooling_eighteen])
    dot_300 = Dot(name = "dot_300", normalize = True, axes = -1)([pooling_seventeen, pooling_nineteen])
    dot_301 = Dot(name = "dot_301", normalize = True, axes = -1)([pooling_seventeen, pooling_twenty])
    dot_302 = Dot(name = "dot_302", normalize = True, axes = -1)([pooling_seventeen, pooling_twentyone])
    dot_303 = Dot(name = "dot_303", normalize = True, axes = -1)([pooling_seventeen, pooling_twentytwo])
    dot_304 = Dot(name = "dot_304", normalize = True, axes = -1)([pooling_seventeen, pooling_twentythree])
    dot_305 = Dot(name = "dot_305", normalize = True, axes = -1)([pooling_seventeen, pooling_twentyfour])
    dot_306 = Dot(name = "dot_306", normalize = True, axes = -1)([pooling_seventeen, pooling_twentyfive])
    dot_307 = Dot(name = "dot_307", normalize = True, axes = -1)([pooling_seventeen, pooling_twentysix])
    dot_308 = Dot(name = "dot_308", normalize = True, axes = -1)([pooling_seventeen, pooling_twentyseven])
    dot_309 = Dot(name = "dot_309", normalize = True, axes = -1)([pooling_seventeen, pooling_twentyeight]) 
    dot_311 = Dot(name = "dot_311", normalize = True, axes = -1)([pooling_eighteen, pooling_nineteen])
    dot_312 = Dot(name = "dot_312", normalize = True, axes = -1)([pooling_eighteen, pooling_twenty])
    dot_313 = Dot(name = "dot_313", normalize = True, axes = -1)([pooling_eighteen, pooling_twentyone])
    dot_314 = Dot(name = "dot_314", normalize = True, axes = -1)([pooling_eighteen, pooling_twentytwo])
    dot_315 = Dot(name = "dot_315", normalize = True, axes = -1)([pooling_eighteen, pooling_twentythree])
    dot_316 = Dot(name = "dot_316", normalize = True, axes = -1)([pooling_eighteen, pooling_twentyfour])
    dot_317 = Dot(name = "dot_317", normalize = True, axes = -1)([pooling_eighteen, pooling_twentyfive])
    dot_318 = Dot(name = "dot_318", normalize = True, axes = -1)([pooling_eighteen, pooling_twentysix])
    dot_319 = Dot(name = "dot_319", normalize = True, axes = -1)([pooling_eighteen, pooling_twentyseven])
    dot_320 = Dot(name = "dot_320", normalize = True, axes = -1)([pooling_eighteen, pooling_twentyeight])
    dot_322 = Dot(name = "dot_322", normalize = True, axes = -1)([pooling_nineteen, pooling_twenty])
    dot_323 = Dot(name = "dot_323", normalize = True, axes = -1)([pooling_nineteen, pooling_twentyone])
    dot_324 = Dot(name = "dot_324", normalize = True, axes = -1)([pooling_nineteen, pooling_twentytwo])
    dot_325 = Dot(name = "dot_325", normalize = True, axes = -1)([pooling_nineteen, pooling_twentythree])
    dot_326 = Dot(name = "dot_326", normalize = True, axes = -1)([pooling_nineteen, pooling_twentyfour])
    dot_327 = Dot(name = "dot_327", normalize = True, axes = -1)([pooling_nineteen, pooling_twentyfive])
    dot_328 = Dot(name = "dot_328", normalize = True, axes = -1)([pooling_nineteen, pooling_twentysix])
    dot_329 = Dot(name = "dot_329", normalize = True, axes = -1)([pooling_nineteen, pooling_twentyseven])
    dot_330 = Dot(name = "dot_330", normalize = True, axes = -1)([pooling_nineteen, pooling_twentyeight])
    dot_332 = Dot(name = "dot_332", normalize = True, axes = -1)([pooling_twenty, pooling_twentyone])
    dot_333 = Dot(name = "dot_333", normalize = True, axes = -1)([pooling_twenty, pooling_twentytwo])
    dot_334 = Dot(name = "dot_334", normalize = True, axes = -1)([pooling_twenty, pooling_twentythree])
    dot_335 = Dot(name = "dot_335", normalize = True, axes = -1)([pooling_twenty, pooling_twentyfour])
    dot_336 = Dot(name = "dot_336", normalize = True, axes = -1)([pooling_twenty, pooling_twentyfive])
    dot_337 = Dot(name = "dot_337", normalize = True, axes = -1)([pooling_twenty, pooling_twentysix])
    dot_338 = Dot(name = "dot_338", normalize = True, axes = -1)([pooling_twenty, pooling_twentyseven])
    dot_339 = Dot(name = "dot_339", normalize = True, axes = -1)([pooling_twenty, pooling_twentyeight])
    dot_341 = Dot(name = "dot_341", normalize = True, axes = -1)([pooling_twentyone, pooling_twentytwo])
    dot_342 = Dot(name = "dot_342", normalize = True, axes = -1)([pooling_twentyone, pooling_twentythree])
    dot_343 = Dot(name = "dot_343", normalize = True, axes = -1)([pooling_twentyone, pooling_twentyfour])
    dot_344 = Dot(name = "dot_344", normalize = True, axes = -1)([pooling_twentyone, pooling_twentyfive])
    dot_345 = Dot(name = "dot_345", normalize = True, axes = -1)([pooling_twentyone, pooling_twentysix])
    dot_346 = Dot(name = "dot_346", normalize = True, axes = -1)([pooling_twentyone, pooling_twentyseven])
    dot_347 = Dot(name = "dot_347", normalize = True, axes = -1)([pooling_twentyone, pooling_twentyeight])
    dot_349 = Dot(name = "dot_349", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentythree])
    dot_350 = Dot(name = "dot_350", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentyfour])
    dot_351 = Dot(name = "dot_351", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentyfive])
    dot_352 = Dot(name = "dot_352", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentysix])
    dot_353 = Dot(name = "dot_353", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentyseven])
    dot_354 = Dot(name = "dot_354", normalize = True, axes = -1)([pooling_twentytwo, pooling_twentyeight])
    dot_356 = Dot(name = "dot_356", normalize = True, axes = -1)([pooling_twentythree, pooling_twentyfour])
    dot_357 = Dot(name = "dot_357", normalize = True, axes = -1)([pooling_twentythree, pooling_twentyfive])
    dot_358 = Dot(name = "dot_358", normalize = True, axes = -1)([pooling_twentythree, pooling_twentysix])
    dot_359 = Dot(name = "dot_359", normalize = True, axes = -1)([pooling_twentythree, pooling_twentyseven])
    dot_360 = Dot(name = "dot_360", normalize = True, axes = -1)([pooling_twentythree, pooling_twentyeight])
    dot_361 = Dot(name = "dot_361", normalize = True, axes = -1)([pooling_twentyfour, pooling_twentyfive])
    dot_362 = Dot(name = "dot_362", normalize = True, axes = -1)([pooling_twentyfour, pooling_twentysix])
    dot_363 = Dot(name = "dot_363", normalize = True, axes = -1)([pooling_twentyfour, pooling_twentyseven])
    dot_364 = Dot(name = "dot_364", normalize = True, axes = -1)([pooling_twentyfour, pooling_twentyeight])
    dot_365 = Dot(name = "dot_365", normalize = True, axes = -1)([pooling_twentyfive, pooling_twentysix])
    dot_366 = Dot(name = "dot_366", normalize = True, axes = -1)([pooling_twentyfive, pooling_twentyseven])
    dot_367 = Dot(name = "dot_367", normalize = True, axes = -1)([pooling_twentyfive, pooling_twentyeight])
    dot_368 = Dot(name = "dot_368", normalize = True, axes = -1)([pooling_twentysix, pooling_twentyseven])
    dot_369 = Dot(name = "dot_369", normalize = True, axes = -1)([pooling_twentysix, pooling_twentyeight])
    dot_370 = Dot(name = "dot_370", normalize = True, axes = -1)([pooling_twentyseven, pooling_twentyeight])
    
    # Interaction gate
    sum_interaction = Add(name = "interaction_gate")([dot_1, dot_2, dot_3, dot_4, dot_5, dot_6, dot_7, dot_8, 
                                                     dot_9, dot_10, dot_11, dot_12, dot_13, dot_14, dot_15, dot_16,
                                                     dot_17, dot_18, dot_19, dot_20, dot_21, dot_22, dot_23, dot_24, 
                                                     dot_25, dot_26, dot_27, dot_28, dot_29, dot_30, dot_31, dot_32,
                                                     dot_33, dot_34, dot_35, dot_36, dot_37, dot_38, dot_39, dot_40, 
                                                     dot_41, dot_42, dot_43, dot_44, dot_45, dot_46, dot_47, dot_48,
                                                     dot_49, dot_50, dot_51, dot_52, dot_53, dot_54, dot_55, dot_56,
                                                     dot_57, dot_58, dot_59, dot_60, dot_61, dot_62, dot_63, dot_64,
                                                     dot_65, dot_66, dot_67, dot_68, dot_69, dot_70, dot_71, dot_72,
                                                     dot_73, dot_74, dot_75, dot_76, dot_77, dot_78, dot_79, dot_80,
                                                     dot_81, dot_82, dot_83, dot_84, dot_85, dot_86, dot_87, dot_88,
                                                     dot_89, dot_90, dot_91, dot_92, dot_93, dot_94, dot_95, dot_96, 
                                                     dot_97, dot_98, dot_99, dot_100, dot_101, dot_102, dot_103, dot_104,
                                                     dot_105, dot_106, dot_107, dot_108, dot_109, dot_110, dot_111, 
                                                     dot_112, dot_113, dot_114, dot_115, dot_116, dot_117, dot_118, dot_119,
                                                     dot_120, dot_121, dot_122, dot_123, dot_124, dot_125, dot_126, dot_127,
                                                     dot_128, dot_129, dot_130, dot_131, dot_132, dot_133, dot_134, dot_135,
                                                     dot_136, dot_137, dot_138, dot_139, dot_140, dot_141, dot_142, dot_143, 
                                                     dot_144, dot_145, dot_146, dot_147, dot_148, dot_149, dot_150, dot_151, 
                                                     dot_152, dot_153, dot_154, dot_155, dot_156, dot_157, dot_158, dot_159,
                                                     dot_160, dot_161, dot_162, dot_163, dot_164, dot_165, dot_166, dot_167,
                                                     dot_168, dot_169, dot_170, dot_171, dot_172, dot_173, dot_174, dot_175,])
                                                    
    
    # Fully connected layer 
    merged = Dense(1, activation = "sigmoid")(sum_interaction)
    model = Model(inputs = [city, country, hotel, rating, popularity,
                           locality, price, landmark], outputs = merged)
    model.compile(optimizer = "Adadelta", loss = "binary_crossentropy", metrics = ["accuracy"])
    
    return model

# Instantiate model and show parameters
model = hotel_embeddings()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# city (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# country (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# hotel (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# rating (InputLayer)             (None, 1)            0
# __________________________________________________________________________________________________
# locality (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# ...

# %%
# Train Model

n_positive = 2000

# Create generator 
generator = generate_batch(hotel_tuples, n_positive, negative_ratio = 1)

# Train

item_property = model.fit_generator(generator, epochs = 100, 
                                    steps_per_epoch = len(hotel_tuples) // n_positive, verbose = 2)
# Out:
# Epoch 1/100
#  - 7s - loss: 0.6922 - acc: 0.5885
# Epoch 2/100
#  - 1s - loss: 0.6917 - acc: 0.5838
# Epoch 3/100
#  - 2s - loss: 0.6909 - acc: 0.5883
# Epoch 4/100
#  - 1s - loss: 0.6893 - acc: 0.6105
# Epoch 5/100
#  - 1s - loss: 0.6881 - acc: 0.6060
# Epoch 6/100
#  - 1s - loss: 0.6883 - acc: 0.5734
# Epoch 7/100
#  - 1s - loss: 0.6857 - acc: 0.5942
# Epoch 8/100
#  - 1s - loss: 0.6846 - acc: 0.5958
# Epoch 9/100
#  - 1s - loss: 0.6851 - acc: 0.5457
# Epoch 10/100
#  - 1s - loss: 0.6792 - acc: 0.6023
# Epoch 11/100
#  - 1s - loss: 0.6729 - acc: 0.6303
# Epoch 12/100
#  - 1s - loss: 0.6628 - acc: 0.6573
# Epoch 13/100
#  - 1s - loss: 0.6516 - acc: 0.6421
# Epoch 14/100
#  - 1s - loss: 0.6386 - acc: 0.6013
# Epoch 15/100
#  - 1s - loss: 0.6161 - acc: 0.6077
# Epoch 16/100
#  - 1s - loss: 0.5999 - acc: 0.6266
# Epoch 17/100
#  - 1s - loss: 0.5910 - acc: 0.6512
# Epoch 18/100
#  - 2s - loss: 0.5820 - acc: 0.5824
# Epoch 19/100
#  - 1s - loss: 0.5420 - acc: 0.6348
# Epoch 20/100
# ...

# %%
# Save model
model.save("../models/embeddings_fourth_attempt.h5")
model.save_weights("../models/embeddings_fourth_attempt_weights.h5")
